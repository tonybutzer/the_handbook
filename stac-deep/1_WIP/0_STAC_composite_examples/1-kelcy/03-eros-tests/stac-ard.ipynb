# %% [markdown]
# # STAC API Functions
#
# Functions for talking to a stac-server implementation.

# %%
#! pip install geopandas

# %%
from functools import lru_cache
import time
from typing import Union

import requests

_stac = 'https://ibhoyw8md9.execute-api.us-west-2.amazonaws.com/prod'

def get_json(url: str, params: Union[list, dict, None] = None) -> Union[list, dict]:
    """
    Perform a GET request to a REST API endpoint, assume the response is a JSON
    """
    resp = requests.get(url, params=params, timeout=5)
    
    if not resp.ok:
        resp.raise_for_status()

    return resp.json()

def post_json(url: str, data: Union[list, dict]) -> Union[list, dict]:
    """
    Send a POST request to the resource with the payload as JSON
    """
    resp = requests.post(url, json=data, timeout=5)
    
    if not resp.ok:
        resp.raise_for_status()
        
    return resp.json()

@lru_cache()
def search_endpoint(endpoint: str = _stac) -> str:
    """
    Get the search endpoint for STAC
    """
    resp = get_json(endpoint)
    
    for item in resp['links']:
        if item['rel'] == 'search':
            return item['href']
        
def get_next(resp: dict) -> Union[str, None]:
    for link in resp['links']:
        if link['rel'] == 'next':
            return link['body']

def stac_query(query_params: dict, endpoint: str = _stac) -> Union[list, dict]:
    """
    Perform query against the STAC API, and iterate through the pages of results to grab everything
    
    All we really care about are the 'features' that get returned from the query results
    """
    resp = post_json(search_endpoint(endpoint), data=query_params)
#     return resp
    feat = resp['features']
    nxt = get_next(resp)

    if nxt:
        feat.extend(stac_query(nxt, endpoint))

    return feat

# %% [markdown]
# # Geospatial Functions
#
# Functions for generating boundaries in the ARD CRS.

# %%
from typing import Tuple
import geopandas as gpd
from shapely.geometry import Polygon

def regional_affine(region: str) -> Tuple[int, int, int, int, int, int]:
    """
    Return the various regional ARD GeoTransforms
    """
    if region == 'cu':
        return -2565585, 150000, 0, 3314805, 0, -150000
    elif region == 'ak':
        return -851715, 150000, 0, 2474325, 0, -150000
    elif region == 'hi':
        return -444345, 150000, 0, 2168895, 0, -150000
    else:
        raise ValueError('Unrecognized region')
        
def regional_wkt(region: str) -> str:
    """
    Return the various regional ARD projection information
    """
    if region == 'cu':
        return 'PROJCS["Albers",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378140,298.2569999999957,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]]]'
    elif region == 'ak':
        return 'PROJCS["Albers",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378140,298.2569999999986,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["standard_parallel_1",55],PARAMETER["standard_parallel_2",65],PARAMETER["latitude_of_center",50],PARAMETER["longitude_of_center",-154],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]]]'
    elif region == 'hi':
        return 'PROJCS["Albers",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378140,298.2569999999986,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["standard_parallel_1",8],PARAMETER["standard_parallel_2",18],PARAMETER["latitude_of_center",3],PARAMETER["longitude_of_center",-157],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]]]'
    else:
        raise ValueError('Unrecognized region')

def tile_ul(h: int, v: int, region: str) -> Tuple[int, int]:
    """
    Determine the upper-left x/y for an ARD tile.
    """
    affine = regional_affine(region)
    xmin = affine[0] + h * 5000 * 30
    ymax = affine[3] - v * 5000 * 30

    return xmin, ymax

def tile_lr(h: int, v: int, region: str) -> Tuple[int, int]:
    """
    Determine the lower-right x/y for an ARD tile.
    """
    return tile_ul(h + 1, v + 1, region)

def tile_ur(h: int, v: int, region: str) -> Tuple[int, int]:
    """
    Determine the upper-right x/y for an ARD tile.
    """
    return tile_ul(h + 1, v, region)

def tile_ll(h: int, v: int, region: str) -> Tuple[int, int]:
    """
    Determine the lower-left x/y for an ARD tile.
    """
    return tile_ul(h, v + 1, region)

def tile_bounds(h: int, v: int, region: str) -> gpd.GeoDataFrame:
    """
    Build a GeoDataFrame object for a tile
    """
    return gpd.GeoDataFrame([{'h': h,
                              'v': v,
                              'geometry': Polygon([tile_ul(h, v, region),
                                                   tile_ur(h, v, region),
                                                   tile_lr(h, v, region),
                                                   tile_ll(h, v, region)])}]).set_crs(regional_wkt(region))

# %%
def query_tile(h: int, v: int, region: str):
    """
    Example function for querying the stac-server for all the c2l2-sr scenes that intersect a given tile.
    """
    query = {'bbox': f"[{','.join(str(_) for _ in tile_bounds(h, v, region).to_crs('EPSG:4326')['geometry'][0].bounds)}]",
             'limit': 300,
             'datetime': '1984-01-01/2020-12-31',
             'collections': ['landsat-c2l2-sr']}
    
    return stac_query(query)

# %%
h, v = 3, 10
region = 'cu'

t1 = time.time()
items = query_tile(h, v, region)
print(time.time() - t1)
# Out:
# 36.170605421066284

# %%
len(items)
# Out:
# 7269

# %%
dir(items)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
for item in items:
    print(item)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LE07_L2SP_041035_20160223_20200903_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-119.15317583314766, 35.09130229317918, -116.5744722302763, 36.99299292146264], 'geometry': {'type': 'Polygon', 'coordinates': [[[-118.70270380086754, 36.99299292146264], [-119.15317583314766, 35.402146044139535], [-117.06242444859552, 35.09130229317918], [-116.5744722302763, 36.67991864125531], [-118.70270380086754, 36.99299292146264]]]}, 'properties': {'datetime': '2016-02-23T18:29:48.207723Z', 'eo:cloud_cover': 9, 'view:sun_azimuth': 149.28654416, 'view:sun_elevation': 38.95605496, 'platform': 'LANDSAT_7', 'instruments': ['ETM'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 9, 'landsat:wrs_type': '2', 'landsat:wrs_path': '041', 'landsat:wrs_row': '035', 'landsat:scene_id': 'LE70410352016054EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7181, 8191], 'proj:transform': [30, 0, 297585, 0, -30, 4097115], 'created': '2021-07-24T15:25:52.297Z', 'updated': '2021-07-24T15:25:52.298Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1_thumb_small.jpeg'}}, 'file:checksum': '13409171f553338588306f25c771dbda770edaf81142e040e24028b91ac3876b2a06af20c335a8d1b68bb6eb6999918fc1cf4867de3ad2f8a84fe779283a28882a82'}, 'reduced_resolution_browse': {'title': 'Reduced resolution browse image', 'type': 'image/jpeg', 'roles': ['overview'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1_thumb_large.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1_thumb_large.jpeg'}}, 'file:checksum': '13406bd139cd6cacf912a52657a2b9d24c5895e16b768d5d7d1ee886b7367ccdaf5410f63c7a807c2b815f08fb6dd4359d2057eb575c5e5f1ce86a675ee22b7f0a10'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_L2SP_041035_20160223_20200903_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/041/035/LE07_L2SP_041035_20160223_20200903_02_T1/LE07_ ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LE07_L2SP_041034_20160223_20200903_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-118.75429316200058, 36.515667615214774, -116.12836654905463, 38.43064054729521], 'geometry': {'type': 'Polygon', 'coordinates': [[[-118.2939498885354, 38.43064054729521], [-118.75429316200058, 36.83189355112326], [-116.62898186708225, 36.515667615214774], [-116.12836654905463, 38.10361375113592], [-118.2939498885354, 38.43064054729521]]]}, 'properties': {'datetime': '2016-02-23T18:29:24.318854Z', 'eo:cloud_cover': 20, 'view:sun_azimuth': 150.22748522, 'view:sun_elevation': 37.84907326, 'platform': 'LANDSAT_7', 'instruments': ['ETM'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 20, 'landsat:wrs_type': '2', 'landsat:wrs_path': '041', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LE70410342016054EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7211, 8181], 'proj:transform': [30, 0, 337185, 0, -30, 4256115], 'created': '2021-07-24T15:28:08.238Z', 'updated': '2021-07-24T15:28:08.238Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', '
160222_20200907_02_T1'}, 'coastal': {'title': 'Coastal/Aerosol Band (B1)', 'description': 'Collection 2 Level-2 Coastal/Aerosol Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'coastal', 'gsd': 30, 'center_wavelength': 0.44}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/042/035/LC08_L2SP_042035_20160222_20200907_02_T1/LC08_L2SP_042035_20160222_20200907_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level- ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LC08_L2SP_042034_20160222_20200907_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-120.2914397556367, 36.41537041407755, -117.73209559365854, 38.52140210768345], 'geometry': {'type': 'Polygon', 'coordinates': [[[-119.79823633134721, 38.52140210768345], [-120.2914397556367, 36.80277378946839], [-118.27009358450314, 36.41537041407755], [-117.73209559365854, 38.13322592653241], [-119.79823633134721, 38.52140210768345]]]}, 'properties': {'datetime': '2016-02-22T18:33:36.739414Z', 'eo:cloud_cover': 1.65, 'view:sun_azimuth': 149.80239696, 'view:sun_elevation': 37.29222597, 'platform': 'LANDSAT_8', 'instruments': ['OLI', 'TIRS'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 1.65, 'landsat:wrs_type': '2', 'landsat:wrs_path': '042', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LC80420342016053LGN01', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7941, 7821], 'proj:transform': [30, 0, 204285, 0, -30, 4268115], 'created': '2021-07-25T16:37:24.296Z', 'updated': '2021-07-25T16:37:24.296Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/042/034/LC08_L2SP_042034_20160222_20200907_02_T1/LC08_L2SP_042034_20160222_20200907_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/oli-tirs/2016/042/034/LC08_L2SP_042034_20160222_20200907_02_T1/LC08_L2SP_042034_20160222_20200907_02_T1_thumb_small.jpeg'}}, 'file:checksum': '1
07_L2SP_043034_20160221_20200903_02_T1/LE07_L2SP_043034_20160221_20200903_02_T1_thumb_large.jpeg'}}, 'file:checksum': '1340cf5b7e13fbc35a0e0a16a6463006d855c0d9e98e0b7a69267b9c7d83e1d3633886b76c77f63279fd617afcbf15b842fbf2ae39b0b40c45e0b8d8d9bbadf037c1'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2016/043/034/LE07_L2SP_043034_20160221_20200903_02_T1/LE07_L2SP_043034_20160221_20200903_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/043/034/LE07_L2SP_043034_20160221_20200903_02_T1/LE07_L2SP_043034_20160221_20200903_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/043/034/LE07_L2SP_043034_20160221_20200903_02_T1/LE07_L2S ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LC08_L2SP_041036_20160215_20200907_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-119.52763314822876, 33.55298715719542, -117.06619338762825, 35.65632093690763], 'geometry': {'type': 'Polygon', 'coordinates': [[[-119.06256133205474, 35.65632093690763], [-119.52763314822876, 33.93421645806085], [-117.57126330839749, 33.55298715719542], [-117.06619338762825, 35.27470946947867], [-119.06256133205474, 35.65632093690763]]]}, 'properties': {'datetime': '2016-02-15T18:28:15.686698Z', 'eo:cloud_cover': 0.58, 'view:sun_azimuth': 149.13311503, 'view:sun_elevation': 37.18633044, 'platform': 'LANDSAT_8', 'instruments': ['OLI', 'TIRS'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 0.63, 'landsat:wrs_type': '2', 'landsat:wrs_path': '041', 'landsat:wrs_row': '036', 'landsat:scene_id': 'LC80410362016046LGN01', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7881, 7751], 'proj:transform': [30, 0, 264285, 0, -30, 3948315], 'created': '2021-07-25T19:10:28.456Z', 'updated': '2021-07-25T19:10:28.456Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1_thumb_small.jpeg'}}, 'file:checksum': '134075bfdd29fc85d64ea84807dae04d14f214b642ff5263fc39cde2806568876654c04c82f513c3de5fb04117629e65f08a0d7d5fcc3f6248659bb5764ca0c387b8'}, 'reduced_resolution_browse': {'title': 'Reduced resolution browse image', 'type': 'image/jpeg', 'roles': ['overview'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1_thumb_large.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1_thumb_large.jpeg'}}, 'file:checksum': '1340467d73131b19a5617c5c7d5c1e98e92469bb567bcb084ea41b93f7d3238fc9708afef68f4f98314b196318495fe209ac840e8634269b68faf9ad6acb53321300'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1'}, 'coastal': {'title': 'Coastal/Aerosol Band (B1)', 'description': 'Collection 2 Level-2 Coastal/Aerosol Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'coastal', 'gsd': 30, 'center_wavelength': 0.44}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/041/036/LC08_L2SP_041036_20160215_20200907_02_T1/LC08_L2SP_041036_20160215_20200907_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2 ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.
160215_20200907_02_T1/LC08_L2SP_041035_20160215_20200907_02_T1'}, 'coastal': {'title': 'Coastal/Aerosol Band (B1)', 'description': 'Collection 2 Level-2 Coastal/Aerosol Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'coastal', 'gsd': 30, 'center_wavelength': 0.44}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/041/035/LC08_L2SP_041035_20160215_20200907_02_T1/LC08_L2SP_041035_20160215_20200907_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/leve ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LC08_L2SP_041034_20160215_20200907_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-118.74352407922672, 36.41449678286123, -116.18654895766826, 38.52163922795742], 'geometry': {'type': 'Polygon', 'coordinates': [[[-118.25428231290746, 38.52163922795742], [-118.74352407922672, 36.802036979583924], [-116.72081474748958, 36.41449678286123], [-116.18654895766826, 38.13323146842752], [-118.25428231290746, 38.52163922795742]]]}, 'properties': {'datetime': '2016-02-15T18:27:27.908859Z', 'eo:cloud_cover': 37.93, 'view:sun_azimuth': 150.8705342, 'view:sun_elevation': 34.96089896, 'platform': 'LANDSAT_8', 'instruments': ['OLI', 'TIRS'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 37.93, 'landsat:wrs_type': '2', 'landsat:wrs_path': '041', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LC80410342016046LGN01', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7871, 7741], 'proj:transform': [30, 0, 342285, 0, -30, 4265115], 'created': '2021-07-25T15:24:10.135Z', 'updated': '2021-07-25T15:24:10.135Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2016/041/034/LC08_L2SP_041034_20160215_20200907_02_T1/LC08_L2SP_041034_20160215_20200907_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/oli-tirs/2016/041/034/LC08_L2SP_041034_20160215_20200907_02_T1/LC08_L2SP_041034_20160215_20200907_02_T1
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LE07_L2SP_042034_20160214_20200903_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-120.32242149969693, 36.51914891198807, -117.69451957793416, 38.42473055541502], 'geometry': {'type': 'Polygon', 'coordinates': [[[-119.86149977792343, 38.42473055541502], [-120.32242149969693, 36.83515978243271], [-118.1984122831124, 36.51914891198807], [-117.69451957793416, 38.105334922335004], [-119.86149977792343, 38.42473055541502]]]}, 'properties': {'datetime': '2016-02-14T18:35:35.486175Z', 'eo:cloud_cover': 68, 'view:sun_azimuth': 151.53978668, 'view:sun_elevation': 34.83613393, 'platform': 'LANDSAT_7', 'instruments': ['ETM'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 68, 'landsat:wrs_type': '2', 'landsat:wrs_path': '042', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LE70420342016045EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7261, 8251], 'proj:transform': [30, 0, 197085, 0, -30, 4258515], 'created': '2021-07-24T15:26:36.770Z', 'updated': '2021-07-24T15:26:36.770Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1_thumb_small.jpeg'}}, 'file:checksum': '1340f67a795654969aa6a7045b253b7c0010c6294a0ecc279c45e2295329934ea513635bf6cc8f43711184b539c79d697ab1b6fb26d12d87e917cca4f6866c05ce1c'}, 'reduced_resolution_browse': {'title': 'Reduced resolution browse image', 'type': 'image/jpeg', 'roles': ['overview'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1_thumb_large.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1_thumb_large.jpeg'}}, 'file:checksum': '13408a004784cc64c3c2a3ed01b6e845d632391ba7141c61e7cc8c4aa652ddddd7c27e43f6d0a01f8e96c12e01a14a53c3e63faa745d6ecea1b8ddca73ac04d735ca'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE07_L2SP_042034_20160214_20200903_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2016/042/034/LE07_L2SP_042034_20160214_20200903_02_T1/LE ...
# ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LT05_L2SP_043034_20000726_20200906_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-121.82746660096063, 36.529224619718605, -119.28659308137762, 38.44659849105816], 'geometry': {'type': 'Polygon', 'coordinates': [[[-121.36108298255066, 38.44659849105816], [-121.82746660096063, 36.83094302359833], [-119.78830859077358, 36.529224619718605], [-119.28659308137762, 38.14245778253438], [-121.36108298255066, 38.44659849105816]]]}, 'properties': {'datetime': '2000-07-26T18:16:59.852031Z', 'eo:cloud_cover': 0, 'view:sun_azimuth': 119.06027854, 'view:sun_elevation': 59.58362281, 'platform': 'LANDSAT_5', 'instruments': ['TM'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 0, 'landsat:wrs_type': '2', 'landsat:wrs_path': '043', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LT50430342000208XXX02', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32610, 'proj:shape': [7081, 7761], 'proj:transform': [30, 0, 599385, 0, -30, 4257915], 'created': '2021-07-25T18:36:53.560Z', 'updated': '2021-07-25T18:36:53.560Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1_thumb_small.jpeg'}}, 'file:checksum': '13409e84727d94b766048eed1d165c4170ffe4602ac7e9a0c2accd3cd460554253fc34371a1d33a5b3b8b14611661aba9fa99cb64fd1b28b1c061b23c3dd76a3dd14'}, 'reduced_resolution_browse': {'title': 'Reduced resolution browse image', 'type': 'image/jpeg', 'roles': ['overview'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1_thumb_large.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1_thumb_large.jpeg'}}, 'file:checksum': '13408f42f2390a31b955406754e427bac7a7b3521c572278ffe01fe347944923d86ae8323b60790491ad57340168216990b88c001fc3f8b800ac6541a2eae2409295'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.49}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_043034_20000726_20200906_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/tm/2000/043/034/LT05_L2SP_043034_20000726_20200906_02_T1/LT05_L2SP_ ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v
200918_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2000/041/035/LE07_L2SP_041035_20000720_20200918_02_T1/LE07_L2SP_041035_20000720_20200918_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2000/041/035/LE07_L2SP_041035_20000720_20200918_02_T1/LE07_ ...
# {'type': 'Feature', 'stac_version': '1.0.0', 'stac_extensions': ['https://landsat.usgs.gov/stac/landsat-extension/v1.1.1/schema.json', 'https://stac-extensions.github.io/view/v1.0.0/schema.json', 'https://stac-extensions.github.io/projection/v1.0.0/schema.json', 'https://stac-extensions.github.io/file/v1.0.0/schema.json', 'https://stac-extensions.github.io/eo/v1.0.0/schema.json', 'https://stac-extensions.github.io/alternate-assets/v1.1.0/schema.json', 'https://stac-extensions.github.io/storage/v1.0.0/schema.json'], 'id': 'LE07_L2SP_041034_20000720_20200917_02_T1_SR', 'description': 'Landsat Collection 2 Level-2 Surface Reflectance Product', 'bbox': [-118.78055764981629, 36.52138304297431, -116.24339617176012, 38.43223741996782], 'geometry': {'type': 'Polygon', 'coordinates': [[[-118.32044350367094, 38.43223741996782], [-118.78055764981629, 36.81852362624338], [-116.74589727470993, 36.52138304297431], [-116.24339617176012, 38.1309076247674], [-118.32044350367094, 38.43223741996782]]]}, 'properties': {'datetime': '2000-07-20T18:18:54.315070Z', 'eo:cloud_cover': 0, 'view:sun_azimuth': 121.92691446, 'view:sun_elevation': 62.87492929, 'platform': 'LANDSAT_7', 'instruments': ['ETM'], 'view:off_nadir': 0, 'landsat:cloud_cover_land': 0, 'landsat:wrs_type': '2', 'landsat:wrs_path': '041', 'landsat:wrs_row': '034', 'landsat:scene_id': 'LE70410342000202EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'landsat:correction': 'L2SP', 'proj:epsg': 32611, 'proj:shape': [7191, 7931], 'proj:transform': [30, 0, 334485, 0, -30, 4256115], 'created': '2021-07-25T11:53:02.101Z', 'updated': '2021-07-25T11:53:02.101Z'}, 'assets': {'thumbnail': {'title': 'Thumbnail image', 'type': 'image/jpeg', 'roles': ['thumbnail'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1_thumb_small.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1_thumb_small.jpeg'}}, 'file:checksum': '1340243997bdd8a34e7a454dd8313a0d2ae66989b9500cabff89024e2aebb04e465aef349b22c45a002984164513aeac3f5274758244e6f1032217523e875f6121bb'}, 'reduced_resolution_browse': {'title': 'Reduced resolution browse image', 'type': 'image/jpeg', 'roles': ['overview'], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1_thumb_large.jpeg', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1_thumb_large.jpeg'}}, 'file:checksum': '1340a3a80c0c2c74ca75ed44fdd7b66650959c4be87b81792858e3c9294aaccfe93a611d37de2013e64c740538c0bb6048342838431ede1c89e9950eaf368cf1c221'}, 'index': {'title': 'HTML index page', 'type': 'text/html', 'roles': ['metadata'], 'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1'}, 'blue': {'title': 'Blue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'roles': ['data'], 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_L2SP_041034_20000720_20200917_02_T1_SR_B1.TIF', 'alternate': {'s3': {'storage:platform': 'AWS', 'storage:requester_pays': True, 'href': 's3://usgs-landsat/collection02/level-2/standard/etm/2000/041/034/LE07_L2SP_041034_20000720_20200917_02_T1/LE07_ ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print((items[0].keys()))
# Out:
# dict_keys(['type', 'stac_version', 'stac_extensions', 'id', 'description', 'bbox', 'geometry', 'properties', 'assets', 'links', 'collection'])

# %%
print(items[0]['assets']['reduced_resolution_browse']['alternate']['s3']['href'])
# Out:
# s3://usgs-landsat/collection02/level-2/standard/oli-tirs/2020/041/036/LC08_L2SP_041036_20201226_20210310_02_T1/LC08_L2SP_041036_20201226_20210310_02_T1_thumb_large.jpeg

# %%
print(items[0]['assets'].keys())
# Out:
# dict_keys(['thumbnail', 'reduced_resolution_browse', 'index', 'coastal', 'blue', 'green', 'red', 'nir08', 'swir16', 'swir22', 'qa_aerosol', 'ANG.txt', 'MTL.txt', 'MTL.xml', 'MTL.json', 'qa_pixel', 'qa_radsat'])

# %%
print(items[0]['assets']['red']['alternate']['s3']['href'])
# Out:
# s3://usgs-landsat/collection02/level-2/standard/oli-tirs/2020/041/036/LC08_L2SP_041036_20201226_20210310_02_T1/LC08_L2SP_041036_20201226_20210310_02_T1_SR_B4.TIF

# %% [markdown]
# # the word standard may mean UTM - if I remember Pete Doucette's definition
