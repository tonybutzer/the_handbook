# %% [markdown]
# # Rich SigNELL Intro
#
# - is a research oceanographer at the US Geological Survey in Woods Hole
# - BS in Atmospheric and Oceanic Science
# - Masters in Physical Oceanography
# - Phd from Woods Hole and MIT
#
# ### I attribute the creation and success of the Pangeo to Rich's leadership and persistence and to Sam Congdon's Kubernetes and AWS Cloud Engineering Skills.
#
# 1. Rich understands the intersections of Science and Technology, and Government Politics.
# 2. Rich is an active contributor to open source - 280 Git Repositories
# 3. Rich's daughter is even smarter than Rich and she helped develop the python panel package.
# 4. Additionally Rich hangs out with smart people in the Pangeo Community (Steering Council Member) and the M$ Planetary Computer Group

# %% [markdown]
# ![](https://avatars.githubusercontent.com/u/1872600?v=4)

# %% [markdown]
# ### Rich's Marching Orders at Woods Hole are:
#
# # Carpe Nubes
#
# - sieze the cloud

# %%
from IPython.display import Image
Image(filename='RobTheilandCloudQoute.JPG')

# %% [markdown]
# ---

# %% [markdown]
# ![](https://prd-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/styles/content_grid/public/thumbnails/image/gen33247signellrich.jpg)

# %% [markdown]
# # Coastal and Marine Hazards and Resources Program
#
# ### Email: rsignell@usgs.gov
