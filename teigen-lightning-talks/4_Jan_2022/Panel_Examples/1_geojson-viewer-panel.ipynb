# %%
from fm_map import Fmap

# %%
def return_map_please(geojson_file):
    f=Fmap(color='red')
    mymap = f.sat_geojson(f'./AOI/{geojson_file}')
    return(mymap)

# %%
from os import listdir
from os.path import isfile, join

def return_geojson_list():
    mypath='AOI'
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    return(onlyfiles)

# %%
import panel as pn
pn.extension()

# %%
geojson_list = return_geojson_list()
print(geojson_list)
# Out:
# ['Waubay_AOI.geojson', 'nogales.geojson', 'rapv2.geojson', 'mini_square_maine.geojson', 'pine-lake.geojson', 'lake_rumira.geojson']

# %%
title = '## Geojson Display Panel App'

geo_select = pn.widgets.Select(name='geo1', options=geojson_list)

@pn.depends(geo_select.param.value)
def refresh_geojson_map(geo1):
    return(return_map_please(geo_select.value))

# %%
row = pn.Row(
    pn.Column(title, pn.panel(refresh_geojson_map, height=600, width=800), geo_select)
)

row.servable()
# Out:
# creating Fmap class
# creating Fmap class</br>
# Row
#     [0] Column
#         [0] Markdown(str)
#         [1] ParamFunction(function, height=600, sizing_mode='fixed', width=800)
#         [2] Select(name='geo1', options=['Waubay_AOI.geojson', ...], value='Waubay_AOI.geojson')

# %% [markdown]
# # next deploy this notebook as a running web site on tendollah machine
#
# 1. login the machine
# 2. clone the teigen repo
#     -
# 3. run the makefile
