# %%
#hello
! ls *.nc
# Out:
# sentinel_sf_all_bands.nc  sf_all_bands.nc

# %%
# %%time
import rioxarray

#See docs for rioxarray.open_rasterio

rds = rioxarray.open_rasterio(
    "sentinel_sf_all_bands.nc"
)
rds
# Out:
# CPU times: user 1.49 s, sys: 340 ms, total: 1.83 s
# Wall time: 1.74 s
# <xarray.Dataset>
# Dimensions:      (time: 36, x: 1780, y: 2021)
# Coordinates:
#   * y            (y) float64 4.832e+06 4.832e+06 ... 4.812e+06 4.812e+06
#   * x            (x) float64 6.741e+05 6.742e+05 ... 6.919e+05 6.919e+05
#   * time         (time) object 2020-06-01 17:31:44 ... 2021-10-29 17:31:47
#     spatial_ref  int64 0
# Data variables:
#     B04          (time, y, x) uint16 ...
#     B03          (time, y, x) uint16 ...
#     B02          (time, y, x) uint16 ...
#     B09          (time, y, x) uint16 ...
# Attributes:
#     crs:           EPSG:32614
#     grid_mapping:  spatial_ref

# %%
from nb_animate import nb_animated_timeseries

# %%
# %%time
nb_animated_timeseries(rds,output_path='./sentinel_sf_stretch00.gif',bands = ['B04', 'B03', 'B02'], time_dim='time',  
      percentile_stretch=(.2,.85), interval=1200)
# Out:
# Generating 36 frame animation
#     Exporting animation to ./sentinel_sf_stretch00.gif
# CPU times: user 42 s, sys: 6.28 s, total: 48.3 s
# Wall time: 57.9 s

# %%
# !v
# Out:
# /bin/bash: v: command not found

# %%
! ls
# Out:
#  0_install_odc_pyyaml.ipynb
#  0_simple_dask_test_console.ipynb
#  1_Surviving_the_disaggregation_and_overload_with_references.ipynb
#  2_my_first_odc_stac_newton_hills_lake_lakota_drys_up.ipynb
#  3_simplify_my_first_odc_stac_newton_hills_lake_lakota_drys_up-Copy1.ipynb
#  4_sioux_falls_animations_brought_to_you_by_open_data_cube.ipynb
# '5_make_animated _gif_from_nc.ipynb'
#  6_sentinel_sioux_falls_animations_brought_to_you_by_open_data_cube-Copy1.ipynb
#  7_sentinel_animation_from_netcdf.ipynb
#  8_explore_netcdf_to_tif.ipynb
#  99_Staff_Attendance_Manager_Monitor_Rainy_Days_and_Mondays.ipynb
#  Readme.md
#  Untitled.ipynb
#  __pycache__
#  dask-worker-space
#  green_june_06_cog.tif
#  lakelakota-boatramp.PNG
#  lakota.geojson
#  nb_DEAPlotting.py
#  nb_animate.py
#  nb_animate.py.1
#  phoenix.geojson
#  sentinel_sf_all_bands.nc
#  sentinel_sf_stretch00.gif
#  sf_all_bands.nc
#  sf_animated.gif
#  sf_stretch00.gif
#  siouxfalls2.geojson
