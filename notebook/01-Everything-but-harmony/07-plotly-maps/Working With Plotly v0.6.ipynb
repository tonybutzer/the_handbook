# %% [markdown]
# # <center>Working With Plotly</center>

# %% [markdown]
# <img src="plotly.png">

# %%
#import
import plotly
from plotly import __version__
print (__version__)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# 3.10.0

# %%
#Jupyter setup
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <br>
#
# To save the chart to Plotly Cloud or Plotly Enterprise, use `plotly.plotly.iplot`.
#
# Use py.plot() to return the unique url and optionally open the url.
#
# Use py.iplot() when working in a Jupyter Notebook to display the plot in the notebook.
#
# <br>

# %%
iplot([{"x": [1, 2, 3, 4, 5], "y": [1, 2, 6, 4, 1]}])
# Out:
# <div>
#
#
#             <div id="9cc3bfc9-1a39-434e-b4ad-ff4df72f50f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9cc3bfc9-1a39-434e-b4ad-ff4df72f50f6")) {
#                     Plotly.newPlot(
#                         '9cc3bfc9-1a39-434e-b4ad-ff4df72f50f6',
#                         [{"type": "scatter", "uid": "4cd1b7b7-fa0d-4f0b-a057-763ec7dad02b", "x": [1, 2, 3, 4, 5], "y": [1, 2, 6, 4, 1]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9cc3bfc9-1a39-434e-b4ad-ff4df72f50f6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
import plotly.graph_objs as go
import numpy as np

x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y, contours=dict(coloring='heatmap')),
       go.Scatter(x=x, y=y, mode='markers', marker=dict(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div>
#
#
#             <div id="a1579cad-f32b-4bdb-aded-dd3c5bdb7fb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a1579cad-f32b-4bdb-aded-dd3c5bdb7fb4")) {
#                     Plotly.newPlot(
#                         'a1579cad-f32b-4bdb-aded-dd3c5bdb7fb4',
#                         [{"contours": {"coloring": "heatmap"}, "type": "histogram2dcontour", "uid": "d8c0d3ff-dd0d-4774-8b40-f9acaee3b6ad", "x": [0.932548120352521, 0.3320529534337033, 0.2383650352862311, 0.6132390598001608, 0.5452974225428282, -1.6017545377757407, 0.7013193426187627, -1.4850922311907426, 0.09518497544847832, 0.740976755872241, 0.3930508816778772, -1.8323319047600488, 1.3947800400658437, -1.473512991928596, -0.8159343444610423, 1.0046931302274524, -0.9733644124373797, -0.18161898485783592, 1.144983377012991, -0.037602306499603465, 0.6013472918287563, 0.33241642801179416, 0.024923420124406678, -2.1644015558967626, 0.6604754269655104, -0.012643968720761624, -0.813824062213784, 1.481710685775131, -0.3631668972905724, 1.1661359331509062, 1.9177460278627358, 2.1539497660913525, 0.7755146974073828, -0.5583310643860901, -1.1220259252854172, -0.5611828631622541, 0.2733360892557875, 0.8385181914435822, -1.0213427628416478, 0.9207529180992664, 0.6099365541758961, -0.04437641391262871, -0.5128574761041345, 1.1059935216032517, 1.6274271764933774, 1.3206250716431664, -1.4022668109418304, 0.2709601147862694, -0.7679429751029512, 0.6785950882480264, 0.24397804498388395, -1.5387252405931173, 0.0848181257021165, 0.5469266119493515, -0.7086643746538347, 0.8676210383479517, -0.5156582704317682, 1.7583563740177293, -0.8060843582383989, -0.1406625643526925, 0.6140241211733595, -0.07421848677194987, -0.13161408782919154, 1.3209612339028889, 0.2530859260948598, -1.155100277683794, -0.2315904477029636, 0.08660745755371663, 0.7377856872316639, -0.5445404760442636, 1.1551534669262056, 0.21194070002157972, 0.33037489715313983, 1.135025967398621, -0.5637285033876679, 0.6329219307358233, -1.9441280268847108, -0.83501554723704, -1.0531898763269454, -0.8446950748363086, -1.1932650304971766, -0.3856743127953736, -0.00014307716606004776, -0.39035587497390467, -0.4975896262301144, 1.3588558033406788, 2.3233658363456478, 0.9604559728208543, -0.3688545316645082, 0.396750979114058, 0.6006164172418166, 1.4893109583529303, 1.1061454009830936, -0.7729979409697182, 0.1188370140738417, 1.0757333699641116, 0.274516452017614, 1.034645462775248, 0.2272795508492142, 0.6842975907916363, -0.6846635306774235, -0.1251020876632747, 1.3808717597708169, 0.5773107713483833, -0.02708858727981832, -0.2090910718990288, 1.5684660856459087, -0.7830261083281014, 0.33989327618979753, -0.12337589036259489, -1.4250889294167541, 0.39833886821155945, 0.9739833248867895, 0.4151862256977272, -0.8928543302073759, -0.9599740767054353, 1.0847806403158118, 0.8543903981306941, -1.3071827746171834, -1.2826627319844266, -0.5487759574032752, 0.16650313037755735, 1.5639170722220515, 1.5212016905608328, 0.08705667310080646, -0.6601503349496474, 0.8101635436624226, -0.12747427112315568, -1.0697834147062062, -1.5050099415578289, 0.547405172820408, -1.40205780576566, 1.3550681511000868, 0.9120955514853738, -0.33131048964487636, 2.824912009622655, 0.5951937371005098, -0.6319584911848665, 0.8751078560635344, 1.2409741618709749, -0.5210624140976969, -1.3383968757088136, 0.1285211093112143, 0.5030314494505291, 1.9407926392293737, -0.27868588636331426, -0.360260871730207, -0.5652637139616908, -2.0652793358504735, 1.5740553925429797, -0.26907048316805227, -0.5131520244753822, -0.22078281358287638, -0.18526686061957057, 1.5198490710428987, 1.6291745262600132, -2.57645377885757, -1.0567531235686725, -0.463905190055595, -0.4725966166233442, -1.0036448310445978, -1.1077180719824888, -0.2938488351993129, 0.03323817394106893, 0.5755797286174855, -0.5648028523085428, 2.0695622446013227, -0.954528689700467, 0.43139705225675723, 0.3130721803011729, 0.32663582250201006, -0.7713181504282034, 1.513670646338805, 0.447158677727269, -0.25639936220158976, -1.7525896515380694, 1.2495885214681135, -0.199207659187098, -1.86755357200309, 0.01234961355387135, -0.7427749525677199, 1.2654263825545913, -0.9013161724639454, -1.9786617663895882, 0.8689006076829989, 0.8097219430198825, -0.5403546670635613, -1.40844258698 ...

# %% [markdown]
# # <center>Episode 2</center>

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

# %%
N = 100
example_x = np.random.rand(N)
example_y = np.random.rand(N)

# %%
trace = go.Scatter(
    x = example_x,
    y = example_y,
    mode = 'markers')

# %%
data = [trace]
iplot(data)
# Out:
# <div>
#
#
#             <div id="d037bf6d-ecbd-4b8a-927d-785d86764ac8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d037bf6d-ecbd-4b8a-927d-785d86764ac8")) {
#                     Plotly.newPlot(
#                         'd037bf6d-ecbd-4b8a-927d-785d86764ac8',
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('d037bf6d-ecbd-4b8a-927d-785d86764ac8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#PIE CHART CREATION

# %%
#Expenses

#breakdown each category 
groups = ['Rent','Food','Bills','Miscellaneous']
#create amount
amount = [1000,518,331,277]
#style
colors = ['#d32c58', '#f9b1ee', '#b7f9b1', '#b1f5f9']

trace = go.Pie(labels=groups, values=amount,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=25),
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=3)))

#plot - 
iplot([trace])
# Out:
# <div>
#
#
#             <div id="35cd0551-6e33-4d6a-823b-060906fc3b7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("35cd0551-6e33-4d6a-823b-060906fc3b7a")) {
#                     Plotly.newPlot(
#                         '35cd0551-6e33-4d6a-823b-060906fc3b7a',
#                         [{"hoverinfo": "label+percent", "labels": ["Rent", "Food", "Bills", "Miscellaneous"], "marker": {"colors": ["#d32c58", "#f9b1ee", "#b7f9b1", "#b1f5f9"], "line": {"color": "#000000", "width": 3}}, "textfont": {"size": 25}, "textinfo": "value", "type": "pie", "uid": "45639065-3771-4980-b2f9-9a6e64b69ce0", "values": [1000, 518, 331, 277]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('35cd0551-6e33-4d6a-823b-060906fc3b7a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## <center> Episode 3 </center>

# %%
import pandas as pd

# %%
pubg = pd.read_csv('PUBG.csv')
#pubg.head(10)
df_pubg = pubg.apply(pd.to_numeric, errors='ignore')
df_new_pubg = df_pubg.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-c24d142b8c78> in <module>
# ----> 1 pubg = pd.read_csv('PUBG.csv')
#       2 #pubg.head(10)
#       3 df_pubg = pubg.apply(pd.to_numeric, errors='ignore')
#       4 df_new_pubg = df_pubg.head(10)
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File PUBG.csv does not exist: 'PUBG.csv'

# %%
#df_new_pubg.head(10)

# %%
trace = go.Scatter(x = df_new_pubg['solo_RoundsPlayed'], y= df_new_pubg['solo_Wins'],
                  name ='Rounds Won')
layout = go.Layout(title='PUBG Wins vs Rounds Played',
                   plot_bgcolor='rgb(230, 230,230)', 
                   showlegend=True)
fig = go.Figure(data=[trace], layout=layout)

iplot(fig, filename='test')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-da07965a6031> in <module>
# ----> 1 trace = go.Scatter(x = df_new_pubg['solo_RoundsPlayed'], y= df_new_pubg['solo_Wins'],
#       2                   name ='Rounds Won')
#       3 layout = go.Layout(title='PUBG Wins vs Rounds Played',
#       4                    plot_bgcolor='rgb(230, 230,230)',
#       5                    showlegend=True)
#
# NameError: name 'df_new_pubg' is not defined

# %%
df_bar_pubg = df_pubg.head(30)

# %%
trace1 = go.Bar( 
        x = df_bar_pubg['player_name'],
        y = df_bar_pubg['solo_RoundsPlayed'],
        name= 'Rounds Played')

trace2 = go.Bar( 
        x = df_bar_pubg['player_name'],
        y = df_bar_pubg['solo_Wins'],
        name= 'Wins')

# %%
data = [trace1, trace2]
layout = go.Layout(barmode='group')

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# ## <center> Episode 4 </center>

# %%
df_bar_pubg.head(10)

# %%
import plotly.figure_factory as ff

x = df_bar_pubg['solo_Wins']
y = df_bar_pubg['solo_TimeSurvived']
#z = df_bar_pubg['squad_Heals']

colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]

fig = ff.create_2d_density(
    x, y, colorscale=colorscale,
    hist_color='rgb(255, 237, 222)', point_size=3
)


iplot(fig, filename='histogram_subplots')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0a19274dacf5> in <module>
#       1 import plotly.figure_factory as ff
#       2
# ----> 3 x = df_bar_pubg['solo_Wins']
#       4 y = df_bar_pubg['solo_TimeSurvived']
#       5 #z = df_bar_pubg['squad_Heals']
#
# NameError: name 'df_bar_pubg' is not defined

# %%
df_bar_pubg.head(1)

# %%
#3D Plotly visualization

# %%
plotly.tools.set_credentials_file(username='DemoAccount', api_key='lr1c37zw81')

x = df_bar_pubg['solo_Wins']
y = df_bar_pubg['solo_TimeSurvived']
z = df_bar_pubg['solo_RoundsPlayed']

trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
    size=12,
    color=z,
    colorscale='Viridis',
    opacity=0.8))

data = [trace1]
layout = go.Layout(
    margin=dict(
    l=0,
    r=0,
    b=0,
    t=0)
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-pubg-plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8704b38e44cb> in <module>
#       1 plotly.tools.set_credentials_file(username='DemoAccount', api_key='lr1c37zw81')
#       2
# ----> 3 x = df_bar_pubg['solo_Wins']
#       4 y = df_bar_pubg['solo_TimeSurvived']
#       5 z = df_bar_pubg['solo_RoundsPlayed']
#
# NameError: name 'df_bar_pubg' is not defined

# %% [markdown]
# ## <center>Episode 5 </center>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")

data = [go.Scatter(
          x=df.Date,
          y=df['AAPL.Close'])]

iplot(data)
# Out:
# <div>
#
#
#             <div id="3f564ef6-b4d2-41cb-8c2e-63670abaf864" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f564ef6-b4d2-41cb-8c2e-63670abaf864")) {
#                     Plotly.newPlot(
#                         '3f564ef6-b4d2-41cb-8c2e-63670abaf864',
#                         [{"type": "scatter", "uid": "039d928c-a21f-4223-8f99-dae5ea9875b8", "x": ["2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-27", "2015-04-28", "2015-04
= pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/minoritymajority.csv')

#df name
df_new = df[df['STNAME'].isin(scope)]

# list values
values = df_new['TOT_POP'].tolist()
fips = df_new['FIPS'].tolist()

#have to have the colorscale values at least = to the # of counties
colorscale = ["#2daa4b", "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#ff0000", "#cce6f4",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#9ba991", "#604d74", "#afcbc7",
              "#80b1d3", "#fdb462", "#b3de69", "#fccde5", "#f0c800", "#387e75", "#fce7e7",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#00778b", "#1d2d43", "#460606",
              "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#af3205", "#436e6f", "#f6a2a2",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#5a3791", "#1d2d43", "#0068a0",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#f6c4d2", "#675974", "#bb1212",
              "#d9d9d9", "#bc80bd", "#ccebc5", "#ffed6f", "#ffd03e", "#4f5573", "#327169",
              "#3697dd", "#8dd3c7", "#ffffb3", "#bebada", "#fb8072", "#ea1717", "#66b4de",]

fig = ff.create_choropleth(
      fips=fips, values=values, scope=scope,
      colorscale=colorscale,round_legend_values=True,
      simplify_county=0, simplify_state=0,
      county_outline={'color': 'rgb(15,15,55)', 'width': 0.5},
      state_outline={'width': 0.5},
      legend_title='Population Per County',
      title='California')
    
    
iplot(fig, filename='Choropleth Map Creation')

# %%
# double click legend, you can set min and max values

# %%
https://plot.ly/python/colorscales/

# %%
pip install geopandas==0.3.0
pip install pyshp==1.2.10
pip install shapely==1.6.3

# %%
# tesla = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/tesla-stock-price.csv")

# %%
#plotly.tools.set_credentials_file(username='DemoAccount', api_key='lr1c37zw81')

# %%
# https://plot.ly/python/box-plots/

import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np

x_data = ['Carmelo Anthony', 'Dwyane Wade',
          'Deron Williams', 'Brook Lopez',
          'Damian Lillard', 'David West',]

y0 = np.random.randn(50)-1
y1 = np.random.randn(50)+1
y2 = np.random.randn(50)
y3 = np.random.randn(50)+2
y4 = np.random.randn(50)-2
y5 = np.random.randn(50)+3

y_data = [y0,y1,y2,y3,y4,y5]

colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)', 'rgba(255, 65, 54, 0.5)', 'rgba(207, 114, 255, 0.5)', 'rgba(127, 96, 0, 0.5)']

traces = []

for xd, yd, cls in zip(x_data, y_data, colors):
        traces.append(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            fillcolor=cls,
            marker=dict(
                size=2,
            ),
            line=dict(width=1),
        ))

layout = go.Layout(
    title='Points Scored by the Top 9 Scoring NBA Players in 2012',
    yaxis=dict(
        autorange=True,
        showgrid=True,
        zeroline=True,
        dtick=5,
        gridcolor='rgb(255, 255, 255)',
        gridwidth=1,
        zerolinecolor='rgb(255, 255, 255)',
        zerolinewidth=2,
    ),
    margin=dict(
        l=40,
        r=30,
        b=80,
        t=100,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
    showlegend=False
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)

# %%
#NOTE

trace = go.Heatmap(z= df_bar_pubg['solo_Wins'],
                   x= df_bar_pubg['player_name'],
                   y= df_bar_pubg['solo_RoundsPlayed'])
data=[trace]
iplot(data, filename='labelled-heatmap')
