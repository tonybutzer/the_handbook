# %%
import datacube

dc=datacube.Datacube()

# %%
dc.list_products()
# Out:
#                              name  \
# id
# 9              alos_palsar_mosaic
# 12     ga_ls8c_fractional_cover_2
# 13            ga_ls8c_gm_2_annual
# 7                  ga_ls8c_wofs_2
# 8   ga_ls8c_wofs_2_annual_summary
# 10         ga_ls8c_wofs_2_summary
# 4               ls8_usgs_sr_scene
# 3              usgs_ls8c_level2_2
#
#                                           description   lon  eo_sun_azimuth  \
# id
# 9   ALOS/PALSAR and ALOS-2/PALSAR-2 annual mosaic ...  None             NaN
# 12      Landsat Fractional Cover based on USGS Scenes  None             NaN
# 13                 Annual Geometric Median, Landsat 8  None             NaN
# 7   Historic Flood Mapping Water Observations from...  None             NaN
# 8     Water Observations from Space Annual Statistics  None             NaN
# 10  Water Observations from Space Full History Sta...  None             NaN
# 4   Landsat 8 USGS Collection 1 Higher Level SR sc...  None             NaN
# ...

# %%
dc.list_measurements()
# Out:
#                                                                                                    aliases  \
# product                       measurement
# alos_palsar_mosaic            hh                                                                      [hh]
#                               hv                                                                      [hv]
#                               date                                                                  [date]
#                               linci                              [local incidence angle, linci, incidence]
#                               mask                                                                  [mask]
# ga_ls8c_fractional_cover_2    bs                                                                    [bare]
#                               pv                                                               [green_veg]
# ...

# %%
help(dc.list_measurements)
# Out:
# Help on method list_measurements in module datacube.api.core:
#
# list_measurements(show_archived=False, with_pandas=True) method of datacube.api.core.Datacube instance
#     List measurements for each product
#
#     :param show_archived: include products that have been archived.
#     :param with_pandas: return the list as a Pandas DataFrame, otherwise as a list of dict.
#     :rtype: pandas.DataFrame or list(dict)

# %%
help(dc.find_datasets)
# Out:
# Help on method find_datasets in module datacube.api.core:
#
# find_datasets(**search_terms) method of datacube.api.core.Datacube instance
#     Search the index and return all datasets for a product matching the search terms.
#
#     :param search_terms: see :class:`datacube.api.query.Query`
#     :return: list of datasets
#     :rtype: list[:class:`datacube.model.Dataset`]
#
#     .. seealso:: :meth:`group_datasets` :meth:`load_data` :meth:`find_datasets_lazy`

# %%
ds = dc.find_datasets(
    product='usgs_ls8c_level2_2',
)

# %%
ds[0]
# Out:
# Dataset <id=00d6a34e-280d-5758-80fd-d62a3f4b9a3a type=usgs_ls8c_level2_2 location=s3://deafrica-usgs-c2-data/usgs_ls8c_level2_2/169/059/2017/12/03/usgs_ls8c_level2_2-0-20190905_169059_2017-12-03.odc-metadata.yaml>

# %%
len(ds)
# Out:
# 177666

# %%
type(ds[0])
# Out:
# datacube.model.Dataset

# %%
dir(ds[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_gs',
#  'archived_time',
#  'bounds',
#  'center_time',
#  'crs',
#  'extent',
#  'format',
#  'id',
#  'indexed_by',
#  'indexed_time',
#  'is_active',
#  'is_archived',
#  'key_time',
#  'local_path',
#  'local_uri',
#  'managed',
#  'measurements',
#  'metadata',
#  'metadata_doc',
#  'metadata_doc_without_lineage',
#  'metadata_type',
#  'sources',
#  'time',
#  'transform',
#  'type',
#  'uri_scheme',
#  'uris']

# %%
ds[0].metadata_type
# Out:
# MetadataType(name='eo3_landsat_ard', id_=3)

# %%
ds[0].metadata_doc
# Out:
# {'id': '00d6a34e-280d-5758-80fd-d62a3f4b9a3a',
#  'crs': 'epsg:32637',
#  'grids': {'default': {'shape': [7751, 7601],
#    'transform': [30.0, 0.0, 71385.0, 0.0, -30.0, 276015.0, 0.0, 0.0, 1.0]}},
#  'label': 'usgs_ls8c_level2_2-0-20190905_169059_2017-12-03',
#  'extent': {'lat': {'end': 2.4959339666277263, 'begin': 0.39252900869826096},
#   'lon': {'end': 37.19765037393791, 'begin': 35.14743976609986}},
#  '$schema': 'https://schemas.opendatacube.org/dataset',
#  'lineage': {'source_datasets': {}},
#  'product': {'href': 'https://collections.dea.ga.gov.au/product/usgs_ls8c_level2_2',
#   'name': 'usgs_ls8c_level2_2'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[299415.0, 276015.0],
#     [71385.0, 276015.0],
#     [71385.0, 43485.0],
#     [299415.0, 43485.0],
#     [299415.0, 276015.0]]]},
#  'properties': {'eo:gsd': 30.0,
#   'datetime': '2017-12-03T07:48:42.907887',
#   'eo:platform': 'landsat-8',
#   'odc:producer': 'usgs.gov',
#   'eo:instrument': 'OLI_TIRS',
# ...

# %%
import pickle
pickle.dump( ds, open( "./datacube_datasets_pickle.p", "wb" ) )

# %%
# !ls
# Out:
# Beginners_guide  README.md		       datacube_load_test.ipynb
# Case_studies	 Scripts		       elevation_example.ipynb
# LICENSE		 Using_load_masked_usgs.ipynb  pickle_datasets.ipynb
# RCMRD_Demo	 datacube_datasets_pickle.p

# %%
# !ls -lh datacube_datasets_pickle.p
# Out:
# -rw-r--r-- 1 jovyan users 915M Jan 21 02:00 datacube_datasets_pickle.p

# %%
# !aws s3 ls ga-odc-eros-archive-west
# Out:
# An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied

# %%
# !aws s3 ls ga-africa-provisional
# Out:
# An error occurred (AccessDenied) when calling the ListObjectsV2 operation: Access Denied

# %%
from IPython.display import FileLink, FileLinks
FileLinks('.') #lists all downloadable files on server
# Out:
# ./
#   datacube_load_test.ipynb
#   LICENSE
#   .gitignore
#   Using_load_masked_usgs.ipynb
#   datacube_datasets_pickle.p
#   pickle_datasets.ipynb
#   README.md
#   elevation_example.ipynb
# ./.git/
#   config
#   description
#   packed-refs
#   HEAD
#   index
# ./.git/hooks/
#   applypatch-msg.sample
#   pre-applypatch.sample
#   post-update.sample
#   pre-push.sample
#   commit-msg.sample
#   pre-receive.sample
#   pre-rebase.sample
#   prepare-commit-msg.sample
#   fsmonitor-watchman.sample
#   update.sample
#   pre-commit.sample
# ./.git/info/
#   exclude
# ./.git/logs/
#   HEAD
# ./.git/logs/refs/heads/
#   master
# ./.git/logs/refs/remotes/origin/
#   HEAD
# ./.git/objects/pack/
#   pack-b91fd7785147d427887827332f972813101c5aa7.pack
#   pack-26b5ef6f9a5081bcd929dfcf1e87ddbb92c2a8dc.pack
#   pack-b91fd7785147d427887827332f972813101c5aa7.idx
#   pack-26b5ef6f9a5081bcd929dfcf1e87ddbb92c2a8dc.idx
#   pack-7d3995515f4d5c46b9d41263ec3766de847b1e4b.pack
# ...
