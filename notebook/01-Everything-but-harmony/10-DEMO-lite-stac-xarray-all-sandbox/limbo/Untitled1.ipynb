# %%
# !pip list
# Out:
# Package                Version
# ---------------------- -----------
# adal                   1.2.2
# affine                 2.3.0
# aiohttp                3.6.0
# alembic                1.1.0
# altair                 3.2.0
# antlr4-python3-runtime 4.7.2
# appdirs                1.4.3
# asciitree              0.3.3
# asn1crypto             0.24.0
# async-generator        1.10
# async-timeout          3.0.1
# attrdict               2.0.1
# attrs                  19.1.0
# backcall               0.1.0
# beautifulsoup4         4.8.0
# bleach                 3.1.0
# blinker                1.4
# blosc                  1.8.1
# bokeh                  1.3.4
# boto3                  1.9.224
# botocore               1.12.224
# branca                 0.3.1
# cached-property        1.5.1
# cachetools             2.1.0
# Cartopy                0.17.0
# certifi                2019.6.16
# certipy                0.1.3
# cf-units               2.1.3
# cffi                   1.12.3
# ...

# %%
! ls
# Out:
#  000-demo-pine-lake.ipynb
#  001-demo-lake_rumira.ipynb
# '009-DEMO-hanoi-vietnam-landsat-pds-lake-odc-lite-STAC-via sat-search.ipynb'
#  100-what-region.ipynb
#  10-debug-rio.ipynb
# 'a1-hanoi-vietnam-landsat-pds-lake-odc-lite-STAC-via sat-search-in -SANDBOX.ipynb'
# 'b1-hanoi-vietnam-landsat-pds-lake-odc-lite-STAC-via sat-search-Copy1.ipynb'
#  hanoi2.gif
#  hanoi.gif
#  ipywidgets-demo.ipynb
#  pinelake2.gif
#  pinelake.gif
#  rumira2.gif
#  Untitled1.ipynb
#  Untitled.ipynb
#  untitled.md
