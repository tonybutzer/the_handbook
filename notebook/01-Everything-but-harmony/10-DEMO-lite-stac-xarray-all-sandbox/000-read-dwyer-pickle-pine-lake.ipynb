# %%
import pickle
import os

home = os.getenv("HOME")
full_path = home + '/pickle/' + 'pinelake-dwyer-cube.p'
ds = pickle.load(open( full_path, "rb" ))

# %% [markdown]
# # Xarrays still THE BOMB!
# <img src=https://previews.123rf.com/images/koya79/koya791510/koya79151000140/46401368-cartoon-bomb-3d-illustration.jpg width=20%>

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (datePR: 84, time: 84, x: 436, y: 468)
# Coordinates:
#   * datePR   (datePR) <U18 '2015-01-18_042_035' ... '2013-03-22_042_034'
#   * time     (time) <U10 '2015-01-18' '2015-01-18' ... '2013-03-27' '2013-03-22'
#   * y        (y) float64 4.11e+06 4.11e+06 4.11e+06 ... 4.096e+06 4.096e+06
#   * x        (x) float64 1.623e+05 1.623e+05 1.624e+05 ... 1.753e+05 1.754e+05
# Data variables:
#     red      (datePR, y, x) int16 0 0 0 0 0 0 ... 7390 7473 7846 8176 8406 8148
#     green    (datePR, y, x) int16 0 0 0 0 0 0 ... 8179 8322 8666 8977 9097 8803
#     blue     (datePR, y, x) int16 0 0 0 0 0 0 ... 9093 9155 9305 9413 9498 9388
# Attributes:
#     crs:      EPSG:32611

# %%
# %matplotlib inline
display_color = 'red'
# 
ds[display_color].plot.imshow('x', 'y', col='datePR', col_wrap=4, cmap='prism')

# %% [markdown]
# # MIC Drop!
#
# ![](https://media.tenor.com/images/f134caf5b9dc20579578105a59ce1daa/tenor.gif)

# %% [markdown]
# ### Thanks Mr. Dwyer for inspiring me to reach higher. You too R.J.; you were the best.
