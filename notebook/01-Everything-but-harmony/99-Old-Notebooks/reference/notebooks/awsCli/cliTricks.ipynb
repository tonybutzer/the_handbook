# %%
# %%bash
# aws ec2 describe-instances --output table --query 'Reservations[*].Instances[*].{ID: InstanceId,ST: State.Name, TG: Tags[*].Value}'
# Out:
# ------------------------------------
# |         DescribeInstances        |
# +----------------------+-----------+
# |          ID          |    ST     |
# +----------------------+-----------+
# |  i-0f964e08e49310be7 |  running  |
# +----------------------+-----------+
# ||               TG               ||
# |+--------------------------------+|
# ||  tonyOne                       ||
# |+--------------------------------+|

# %%
# %%bash
# aws ec2 describe-instances --output text --query 'Reservations[*].Instances[*].{ID: InstanceId,ST: State.Name, TG: Tags[*].Value}'
# Out:
# i-0f964e08e49310be7	running
# TG	tonyOne

# %%
# %%bash
# aws s3 ls
# aws s3 ls tbutzer-home-bucket
# Out:
# 2017-08-24 14:14:46 tbutzer-home-bucket
# 2017-08-24 14:27:58    3735556 thomasTelescope.jpg

# %% [markdown]
# ## Tab completion on awscli
#
# ```
#    complete -C aws_completer aws
#
# ```

# %%
# %%bash
#
# aws ec2 describe-instances
# aws ec2 describe-instances --output table
# aws ec2 describe-instances --output text
# aws ec2 describe-regions
# aws ec2 describe-route-tables
# aws ec2 describe-vpcs
# Out:
# {
#     "Reservations": [
#         {
#             "ReservationId": "r-02cc4b4788d907c81",
#             "OwnerId": "366920741278",
#             "Instances": [
#                 {
#                     "RootDeviceName": "/dev/xvda",
#                     "PublicDnsName": "ec2-35-164-50-81.us-west-2.compute.amazonaws.com",
#                     "Placement": {
#                         "Tenancy": "default",
#                         "GroupName": "",
#                         "AvailabilityZone": "us-west-2a"
#                     },
#                     "VirtualizationType": "hvm",
#                     "SecurityGroups": [
#                         {
#                             "GroupName": "launch-wizard-1",
#                             "GroupId": "sg-a08fa9da"
#                         }
#                     ],
#                     "InstanceId": "i-0f964e08e49310be7",
#                     "PublicIpAddress": "35.164.50.81",
# ...

# %%
# %%bash
#  aws iam list-access-keys
# Out:
# {
#     "AccessKeyMetadata": [
#         {
#             "UserName": "tonybutzer",
#             "CreateDate": "2017-08-24T21:49:30Z",
#             "AccessKeyId": "AKIAIVBJIWEHSHQRYJFQ",
#             "Status": "Active"
#         }
#     ]
# }

# %%
# %%bash
# aws cloudwatch describe-alarms
# Out:
# {
#     "MetricAlarms": []
# }
