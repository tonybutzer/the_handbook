# %% [markdown]
# ## P4 ODC Cloud Engineering Weekly
#
# - to: Brian Sauer, Cory Van Batavia
# - from: Tony Butzer
# - Date: 08-31-2017
#
#
# ### Progress
#
# 1. Continued AWS training
# 2. Began investigation of ARD tiles over Washngton State
# 3. Analyzed logging in S3 buckets
# 4. Coordinated with Geoscience Australia
#    - much common ground; much optimism.
# 5. Setup tools for collaboration
#    - github
#    - skype for business
#    - slack
#    - google hangouts
#    - gmail;bison;instant pestering
# 6. Reviewed background information from Mr. Sunne. ; he was a little too eager to dump this. :-)
# 7. Cloud peer interest is high among several folks
#     - Ron Dilley; Rachel Meher; Werpy; Martens; Sunne
# 8. completed EROS onboarding
#    - Badge
#    - Computer
#    - Phone
#    - Office
# 9. Continued Project Planning
# 10. Initial shallow dive into geoTiffs
# 11. Communication Plan - meetings and emails
#    - GA telecons
#    - Tue/Thur - Cloud Standup Meetings
#    - Weekly skype sessions with Sauer; fireside chats
#       - skewered via skype
#
#
# ### Plans - 9/4 --> 9/8
#
# #### Vacation - UTAH
# - Well deserved after only working for one week. :-)
# - After that its more fun with buckets
# - and then some python/gdal : convert to cloud friendly from stock geotiffs
#    - might be prototyped in a jupyter notebook
#    - these P4's are done via a notebook; its all about immersion.
#
# ### Problems
#
# 1. gmail was behaving badly for quite some time; fixed now - yay!
#
# ### Prouds
#
# 1. Starting to gain some momentum and traction on this task.

# %% [markdown]
# ## P4 ODC Cloud Engineering Weekly
#
# - to: Brian Sauer, Cory Van Batavia
# - from: Tony Butzer
# - Date: 08-25-2017
#
# ### Preface
#
# This is a sample P4 - this is one level of reporting we may want to consider for staying up to date on what is happening in Open Data Cube land.
#
# ### Progress
#
# 1. Set up office structure at home with standing desk
# 2. Started AWS training
#    - AWS for dummies
#    - AWS tutrorials
# 3. AWS LABS
#    - signed up for AWS free tier; created ec2.micro instance with 8 Gb storage
#    - AMI credentials
#    - CLI jupyter notebooks
#    - CLI Cheat sheet
#    - Installed Docker on AWS Linux; - easy
#       - Created a kanboard container and tested it
#    - S3 bucket from AWS Management Console
#    - Billing/over-billing alerts set
#
# ### Plans 8/29 --> 9/1
#
# 1. Mostly EROS onboarding
#    - Badge
#    - Computer
#    - Phone
# 2. Begin Project Initiation Steps
# 3. Communication Plan - meetings and emails
# 4. Refine job description and task plans
#
# ### Problems
#
# 1. Will be gone to Utah week of 9/3 --> 9/10; back at EROS on 9/11
#    - need to figure out LWOP and timesheets
#    - timesheets are not a core strength for me
#
# ### Prouds
#
# 1. Acepted a position as ODC Cloud Engineer
# 2. Started to look at the project initiation and scoping for this task
# 3. Conquered the initial AWS Journey - pretty vast canvas

# %% [markdown]
# #HI use the one above
