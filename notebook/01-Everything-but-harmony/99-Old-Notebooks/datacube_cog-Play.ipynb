# %% [markdown]
# # Bucket Info Landsat Collection 1 Level 1

# %% [markdown]
# # Loading Datacube

# %%
import datacube

# %%
# !datacube system check
# Out:
# Version:	1.5.3+5.g3093f2c
# Config files:	datacube.conf
# Host:		localhost:5432
# Database:	datacube
# User:		postgres
#
# Valid connection:	YES

# %% [markdown]
# # Indexed level 1 scenes

# %%
# !datacube product list
# Out:
#    name                     description                                        product_type instrument format   platform
# id
# 3           ls5_level1_usgs       Landsat 5 USGS Level 1 Collection-1 OLI-TIRS  L1TP               TM   GeoTiff  LANDSAT_5
# 2           ls7_level1_usgs       Landsat 7 USGS Level 1 Collection-1 OLI-TIRS  L1TP              ETM   GeoTiff  LANDSAT_7
# 5   ls7_level1_usgs_terrain  Landsat 7 USGS Level 1 Collection-1 Systematic...  L1GT              ETM   GeoTiff  LANDSAT_7
# 4            ls8_l1_pc_usgs     Landsat 8 USGS Level 1 Pre-Collection OLI-TIRS   L1T         OLI_TIRS   GeoTiff  LANDSAT_8
# 1           ls8_level1_usgs       Landsat 8 USGS Level 1 Collection-1 OLI-TIRS  L1TP         OLI_TIRS   GeoTiff  LANDSAT_8
# 6   ls8_level1_usgs_terrain  Landsat 8 USGS Level 1 Collection-1 Systematic...  L1GT         OLI_TIRS   GeoTiff  LANDSAT_8

# %%
# !datacube product show ls8_level1_usgs
# Out:
# {
#     "name": "ls8_level1_usgs",
#     "metadata": {
#         "format": {
#             "name": "GeoTiff"
#         },
#         "platform": {
#             "code": "LANDSAT_8"
#         },
#         "instrument": {
#             "name": "OLI_TIRS"
#         },
#         "product_type": "L1TP"
#     },
#     "description": "Landsat 8 USGS Level 1 Collection-1 OLI-TIRS",
#     "measurements": [
#         {
#             "name": "coastal_aerosol",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_1",
#                 "coastal_aerosol"
#             ]
#         },
#         {
#             "name": "blue",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_2",
#                 "blue"
#             ]
#         },
#         {
#             "name": "green",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_3",
#                 "green"
#             ]
#         },
#         {
#             "name": "red",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_4",
#                 "red"
#             ]
#         },
#         {
#             "name": "nir",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_5",
#                 "nir"
#             ]
#         },
#         {
#             "name": "swir1",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_6",
#                 "swir1"
#             ]
#         },
#         {
#             "name": "swir2",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_7",
#                 "swir2"
#             ]
#         },
#         {
#             "name": "panchromatic",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_8",
#                 "panchromatic"
#             ]
#         },
#         {
#             "name": "cirrus",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_9",
#                 "cirrus"
#             ]
#         },
#         {
#             "name": "lwir1",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_10",
#                 "lwir1"
#             ]
#         },
#         {
#             "name": "lwir2",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": -9999,
#             "aliases": [
#                 "band_11",
#                 "lwir2"
#             ]
#         },
#         {
#             "name": "quality",
#             "dtype": "int16",
#             "units": "1",
#             "nodata": 0,
#             "aliases": [
#                 "QUALITY",
#                 "quality"
#             ],
#             "flags_definition": {
#                 "cloud": {
#                     "bits": [
#                         4
#                     ],
#                     "values": {
#                         "0": false,
#                         "1": true
#                     },
#                     "description": "Cloud"
#                 },
#                 "snow_ice_conf": {
#                     "bits": [
#                         9,
#                         10
#                     ],
#                     "values": {
#                         "0": "Not Determined",
#                         "1": "Low",
#                         "2": "Medium",
#                         "3": "High"
#                     },
#                     "description": "Snow/Ice Confidence with low =(0-33)%, medium =(34-66)% and high =(67-100)%"
#                 },
#                 "designated_fill": {
#                     "bits": [
#                         0
#                     ],
#                     "values": {
#                         "0": false,
#                         "1": true
#                     },
#                     "description": "Used to identify fill values"
#                 },
#                 "cloud_confidence": {
#                     "bits": [
#                         5,
#                         6
#                     ],
#                     "values": {
#                         "0": "Not Determined",
#                         "1": "Low",
#                         "2": "Medium",
#                         "3": "High"
#                     },
#                     "description": "Cloud Confidence with low =(0-33)%, medium =(34-66)% and high =(67-100)%"
#                 },
#                 "cirrus_confidence": {
#                     "bits": [
#                         11,
#                         12
#                     ],
#                     "values": {
#                         "0": "Not Determined",
#                         "1": "Low",
#                         "2": "Medium",
#                         "3": "High"
#                     },
#                     "description": "Cirrus Confidence with low =(0-33)%, medium =(34-66)% and high =(67-100)%"
#                 },
#                 "cloud_shadow_conf": {
#                     "bits": [
#                         7,
#                         8
#                     ],
#                     "values": {
#                         "0": "Not Determined",
#                         "1": "Low",
#                         "2": "Medium",
#                         "3": "High"
#                     },
#                     "description": "Cloud Shadow Confidence with low =(0-33)%, medium =(34-66)% and high =(67-100)%"
#                 },
#                 "terrain_occlusion": {
#                     "bits": [
#                         1
#                     ],
#                     "values": {
#                         "0": false,
#                         "1": true
#                     },
#                     "description": "Terrain Occlusion"
#                 },
#                 "radiometric_saturation": {
#                     "bits": [
#                         2,
#                         3
#                     ],
#                     "values": {
#                         "0": "none",
#                         "1": "1-2",
#                         "2": "3-4",
#                         "3": "<=5"
#                     },
#                     "description": "Radiometric saturation bits, represents how many bands contains saturation"
#                 }
#             }
#         }
#     ],
#     "metadata_type": "eo"
# }

# %%
# !datacube dataset --help
# Out:
# Usage: datacube dataset [OPTIONS] COMMAND [ARGS]...
#
#   Dataset management commands
#
# Options:
#   -h, --help  Show this message and exit.
#
# Commands:
#   add      Add datasets to the Data Cube
#   archive  Archive datasets
#   info     Display dataset information
#   restore  Restore datasets
#   search   Search available Datasets Search...
#   update   Update datasets in the Data Cube

# %%
# !datacube dataset search product =ls7_level1_usgs |grep id |wc
# Out:
#     191     382    7831

# %%
# !datacube dataset search product =ls8_level1_usgs |grep id |wc
# Out:
#      98     196    4018

# %%
# !datacube dataset search product =ls7_level1_usgs_terrain |grep id |wc
# Out:
#      34      68    1394

# %%
# !datacube dataset search product =ls8_level1_usgs_terrain |grep id |wc
# Out:
#      20      40     820

# %% [markdown]
# # To read level1 scenes using datacube

# %%
dc = datacube.Datacube()

# %%
dc.list_measurements()
# Out:
#                                                            aliases  dtype  \
# product                 measurement
# ls5_level1_usgs         blue                        [band_1, blue]  int16
#                         green                      [band_2, green]  int16
#                         red                          [band_3, red]  int16
#                         nir                          [band_4, nir]  int16
#                         swir1                      [band_5, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         quality                 [QUALITY, quality]  int16
# ls7_level1_usgs         blue                        [band_1, blue]  int16
#                         green                      [band_2, green]  int16
#                         red                          [band_3, red]  int16
#                         nir                          [band_4, nir]  int16
#                         swir1                      [band_5, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         quality                 [QUALITY, quality]  int16
# ls7_level1_usgs_terrain blue                        [band_1, blue]  int16
#                         green                      [band_2, green]  int16
#                         red                          [band_3, red]  int16
#                         nir                          [band_4, nir]  int16
#                         swir1                      [band_5, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         quality                 [QUALITY, quality]  int16
# ls8_l1_pc_usgs          coastal_aerosol  [band_1, coastal_aerosol]  int16
#                         blue                        [band_2, blue]  int16
#                         green                      [band_3, green]  int16
#                         red                          [band_4, red]  int16
#                         nir                          [band_5, nir]  int16
#                         swir1                      [band_6, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         panchromatic        [band_8, panchromatic]  int16
#                         cirrus                    [band_9, cirrus]  int16
#                         lwir1                     [band_10, lwir1]  int16
#                         lwir2                     [band_11, lwir2]  int16
#                         quality                 [QUALITY, quality]  int16
# ls8_level1_usgs         coastal_aerosol  [band_1, coastal_aerosol]  int16
#                         blue                        [band_2, blue]  int16
#                         green                      [band_3, green]  int16
#                         red                          [band_4, red]  int16
#                         nir                          [band_5, nir]  int16
#                         swir1                      [band_6, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         panchromatic        [band_8, panchromatic]  int16
#                         cirrus                    [band_9, cirrus]  int16
#                         lwir1                     [band_10, lwir1]  int16
#                         lwir2                     [band_11, lwir2]  int16
#                         quality                 [QUALITY, quality]  int16
# ls8_level1_usgs_terrain coastal_aerosol  [band_1, coastal_aerosol]  int16
#                         blue                        [band_2, blue]  int16
#                         green                      [band_3, green]  int16
#                         red                          [band_4, red]  int16
#                         nir                          [band_5, nir]  int16
#                         swir1                      [band_6, swir1]  int16
#                         swir2                      [band_7, swir2]  int16
#                         panchromatic        [band_8, panchromatic]  int16
#                         cirrus                    [band_9, cirrus]  int16
#                         lwir1                     [band_10, lwir1]  int16
#                         lwir2                     [band_11, lwir2]  int16
#                         quality                 [QUALITY, quality]  int16
#
#                                                                           flags_definition  \
# product                 measurement
# ls5_level1_usgs         blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# ls7_level1_usgs         blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# ls7_level1_usgs_terrain blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# ls8_l1_pc_usgs          coastal_aerosol                                                NaN
#                         blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         panchromatic                                                   NaN
#                         cirrus                                                         NaN
#                         lwir1                                                          NaN
#                         lwir2                                                          NaN
#                         quality          {'water': {'bits': [4, 5], 'values': {'0': Fal...
# ls8_level1_usgs         coastal_aerosol                                                NaN
#                         blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         panchromatic                                                   NaN
#                         cirrus                                                         NaN
#                         lwir1                                                          NaN
#                         lwir2                                                          NaN
#                         quality          {'cloud': {'bits': [4], 'values': {'0': False,...
# ls8_level1_usgs_terrain coastal_aerosol                                                NaN
#                         blue                                                           NaN
#                         green                                                          NaN
#                         red                                                            NaN
#                         nir                                                            NaN
#                         swir1                                                          NaN
#                         swir2                                                          NaN
#                         panchromatic                                                   NaN
#                         cirrus                                                         NaN
#                         lwir1                                                          NaN
#                         lwir2                                                          NaN
#                         quality          {'cloud': {'bits': [4], 'values': {'0': False,...
#
#                                                     name  nodata units
# product                 measurement
# ls5_level1_usgs         blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         quality                  quality       0     1
# ls7_level1_usgs         blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         quality                  quality       0     1
# ls7_level1_usgs_terrain blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         quality                  quality       0     1
# ls8_l1_pc_usgs          coastal_aerosol  coastal_aerosol   -9999     1
#                         blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         panchromatic        panchromatic   -9999     1
#                         cirrus                    cirrus   -9999     1
#                         lwir1                      lwir1   -9999     1
#                         lwir2                      lwir2   -9999     1
#                         quality                  quality       0     1
# ls8_level1_usgs         coastal_aerosol  coastal_aerosol   -9999     1
#                         blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         panchromatic        panchromatic   -9999     1
#                         cirrus                    cirrus   -9999     1
#                         lwir1                      lwir1   -9999     1
#                         lwir2                      lwir2   -9999     1
#                         quality                  quality       0     1
# ls8_level1_usgs_terrain coastal_aerosol  coastal_aerosol   -9999     1
#                         blue                        blue   -9999     1
#                         green                      green   -9999     1
#                         red                          red   -9999     1
#                         nir                          nir   -9999     1
#                         swir1                      swir1   -9999     1
#                         swir2                      swir2   -9999     1
#                         panchromatic        panchromatic   -9999     1
#                         cirrus                    cirrus   -9999     1
#                         lwir1                      lwir1   -9999     1
#                         lwir2                      lwir2   -9999     1
#                         quality                  quality       0     1

# %%
datasets = dc.load(product='ls8_level1_usgs', align=(15,0), dask_chunks={'time':1}, output_crs = 'epsg:32610', resolution = (-30,30), x=(-122.5, -122.8), y=(46,46.6))
# Out:
# dask chunk
# starting
# dataset set up
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# measurements fused

# %%
datasets
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 82, x: 781, y: 2227)
# Coordinates:
#   * time             (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y                (y) float64 5.161e+06 5.161e+06 5.161e+06 5.161e+06 ...
#   * x                (x) float64 5.153e+05 5.154e+05 5.154e+05 5.154e+05 ...
# Data variables:
#     coastal_aerosol  (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     blue             (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     green            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     red              (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     nir              (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     swir1            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     swir2            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     panchromatic     (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     cirrus           (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     lwir1            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     lwir2            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     quality          (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
# Attributes:
#     crs:      epsg:32610

# %%
# %time datasets
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 5.96 µs
# <xarray.Dataset>
# Dimensions:          (time: 82, x: 781, y: 2227)
# Coordinates:
#   * time             (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y                (y) float64 5.161e+06 5.161e+06 5.161e+06 5.161e+06 ...
#   * x                (x) float64 5.153e+05 5.154e+05 5.154e+05 5.154e+05 ...
# Data variables:
#     coastal_aerosol  (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     blue             (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     green            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     red              (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     nir              (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     swir1            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     swir2            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     panchromatic     (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     cirrus           (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     lwir1            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     lwir2            (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
#     quality          (time, y, x) int16 dask.array<shape=(82, 2227, 781), chunksize=(1, 2227, 781)>
# Attributes:
#     crs:      epsg:32610

# %% [markdown]
# # Database 2 COG and Tiled Indexed data

# %%
def Time_smallchunk_cog(product,x,y):
    dc=datacube.Datacube(config = 'test_db.conf')
    data= dc.load(product=product, align = (15,0), dask_chunks={'time':1},  output_crs = 'epsg:32610', resolution = (-30,30), x=x, y=y)
    print(data)

# %%
# %time Time_smallchunk_cog('ls7_level1_usgs_cog', x= (-122.5,-122.6), y = (46,46.1))
# Out:
# dask chunk
# starting
# dataset set up
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# measurements fused
# <xarray.Dataset>
# Dimensions:  (time: 165, x: 261, y: 373)
# Coordinates:
#   * time     (time) datetime64[ns] 1999-07-05T18:48:48.388942 ...
#   * y        (y) float64 5.105e+06 5.105e+06 5.105e+06 5.105e+06 5.105e+06 ...
#   * x        (x) float64 5.309e+05 5.31e+05 5.31e+05 5.31e+05 5.31e+05 ...
# Data variables:
#     blue     (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     green    (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     red      (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     nir      (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     swir1    (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     swir2    (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
#     quality  (time, y, x) int16 dask.array<shape=(165, 373, 261), chunksize=(1, 373, 261)>
# Attributes:
#     crs:      epsg:32610
# CPU times: user 260 ms, sys: 24 ms, total: 284 ms
# Wall time: 299 ms

# %%
# The Time reduces if the chunk size get decreased

# %% [markdown]
# # Landsat 8 COG bucket all bands

# %% [markdown]
# # Landsat 8 tile bucket all bands

# %% [markdown]
# # Single band query on COG data

# %%
def Time_smallchunk_cog_m(product,x,y,m):
    dc=datacube.Datacube(config = 'test_db.conf')
    data= dc.load(product=product, align = (15,0), dask_chunks={'time':1},  output_crs = 'epsg:32610', resolution = (-30,30), x=x, y=y, measurements=m)
    print(data)
    return(data)

# %%
# %time Time_smallchunk_cog_m('ls8_level1_usgs_tile', x= (-123,-123.2), y = (46,46.2), m = ('blue', 'red', 'green'))
# Out:
# dask chunk
# starting
# dataset set up
# reading data
# read data
# reading data
# read data
# reading data
# read data
# measurements fused
# <xarray.Dataset>
# Dimensions:  (time: 82, x: 517, y: 742)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y        (y) float64 5.116e+06 5.116e+06 5.116e+06 5.116e+06 5.116e+06 ...
#   * x        (x) float64 4.845e+05 4.845e+05 4.846e+05 4.846e+05 4.846e+05 ...
# Data variables:
#     blue     (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
#     red      (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
#     green    (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
# Attributes:
#     crs:      epsg:32610
# CPU times: user 132 ms, sys: 0 ns, total: 132 ms
# Wall time: 150 ms
# <xarray.Dataset>
# Dimensions:  (time: 82, x: 517, y: 742)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y        (y) float64 5.116e+06 5.116e+06 5.116e+06 5.116e+06 5.116e+06 ...
#   * x        (x) float64 4.845e+05 4.845e+05 4.846e+05 4.846e+05 4.846e+05 ...
# Data variables:
#     blue     (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
#     red      (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
#     green    (time, y, x) int16 dask.array<shape=(82, 742, 517), chunksize=(1, 742, 517)>
# Attributes:
#     crs:      epsg:32610

# %% [markdown]
# # Time decreases for just 3 bands

# %%
# %time Time_smallchunk_cog('ls8_level1_usgs_cog', x= (-123,-123.1), y = (46.5,46.6))
# Out:
# dask chunk
# starting
# dataset set up
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# reading data
# read data
# measurements fused
# <xarray.Dataset>
# Dimensions:          (time: 82, x: 257, y: 371)
# Coordinates:
#   * time             (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y                (y) float64 5.161e+06 5.161e+06 5.161e+06 5.161e+06 ...
#   * x                (x) float64 4.923e+05 4.923e+05 4.924e+05 4.924e+05 ...
# Data variables:
#     coastal_aerosol  (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     blue             (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     green            (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     red              (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     nir              (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     swir1            (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     swir2            (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     panchromatic     (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     cirrus           (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     lwir1            (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     lwir2            (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
#     quality          (time, y, x) int16 dask.array<shape=(82, 371, 257), chunksize=(1, 371, 257)>
# Attributes:
#     crs:      epsg:32610
# CPU times: user 148 ms, sys: 4 ms, total: 152 ms
# Wall time: 166 ms

# %% [markdown]
# # Query for Single Band

# %%
mydat = Time_smallchunk_cog_m('ls8_level1_usgs_cog', x= (-122.6,-122.8), y = (45.57,45.7), m = ('blue','panchromatic'))
print (mydat)
# Out:
# dask chunk
# starting
# dataset set up
# reading data
# read data
# reading data
# read data
# measurements fused
# <xarray.Dataset>
# Dimensions:       (time: 90, x: 522, y: 484)
# Coordinates:
#   * time          (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y             (y) float64 5.061e+06 5.061e+06 5.061e+06 5.061e+06 ...
#   * x             (x) float64 5.156e+05 5.156e+05 5.156e+05 5.157e+05 ...
# Data variables:
#     blue          (time, y, x) int16 dask.array<shape=(90, 484, 522), chunksize=(1, 484, 522)>
#     panchromatic  (time, y, x) int16 dask.array<shape=(90, 484, 522), chunksize=(1, 484, 522)>
# Attributes:
#     crs:      epsg:32610
# <xarray.Dataset>
# Dimensions:       (time: 90, x: 522, y: 484)
# Coordinates:
#   * time          (time) datetime64[ns] 2013-03-20T18:56:22.263782 ...
#   * y             (y) float64 5.061e+06 5.061e+06 5.061e+06 5.061e+06 ...
#   * x             (x) float64 5.156e+05 5.156e+05 5.156e+05 5.157e+05 ...
# Data variables:
#     blue          (time, y, x) int16 dask.array<shape=(90, 484, 522), chunksize=(1, 484, 522)>
#     panchromatic  (time, y, x) int16 dask.array<shape=(90, 484, 522), chunksize=(1, 484, 522)>
# Attributes:
#     crs:      epsg:32610

# %%
print(mydat.blue[0].shape)
# Out:
# (484, 522)

# %%
from rasterio.plot import show_hist
ary=mydat.panchromatic[3].values
ary = ary * 5
type(ary)
show_hist(ary, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram")
# Out:
# I'm here 1

# %%
from matplotlib import pyplot

pyplot.figure(figsize=(17.5,12.5))
pyplot.imshow(ary, cmap='gray')
#pyplot.imshow(array, cmap='hot')\n",
#pyplot.imshow(array, cmap='pink')\n",    "\n",
pyplot.show()

# %%
ary=mydat.blue[3].values
ary = ary 
type(ary)
show_hist(ary, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram")
# Out:
# I'm here 1

# %%
pyplot.figure(figsize=(17.5,12.5))
pyplot.imshow(ary, cmap='hot')

pyplot.show()

# %%
for i in range(0,10):
    ary=mydat.blue[3].values
