# %% [markdown]
# # Introduction Week2 Class
# > "If I had more time, I would have written a shorter notebook." - Tony Butzer
# - a shorter notebook
# - a notebook
# - a note
#
# ```
# list of attributions I have seen: Mark Twain, George Bernard Shaw, Voltaire, Blaise Pascal, Johann Wolfgang von Goethe, Winston Churchill, Pliny the Younger, Cato, Cicero, Bill Clinton, and Benjamin Franklin
# ```
#
# ### Student of the Month and His Mentor
#
# ![](wylie-pastick.PNG)
# ---
#
# > When we last tuned in, our protagonist, Neal, had just won an NSF grant that came with a mini-pangeo and a project website!
# ---
# > Neal turns to his mentor and longtime friend Bruce and asks - " How do you think we should go about this modeling? "
# ---
# > "Well Neal", replies Bruce - "I think we should start with a small invasive test site and use that xarray approach tony was babling about - I know he is a little off - but i've been reading about xarray for data and it looks really cool! - Boy I could really do some science in that Amazon space, too bad I'm retiring - so many fish; so little time" - Bruce sighs.
# ---
# > "Xarray huh?" - Neal wonders... ...to be continued...
#
# > the notebook author continues to take more and more liberties with the facts; he would have made a great politician.
#
# ---
#
# ## Goals:
# 1. ## get everyone logged into the hub
# 2. ### practice cloning a repo -- `our bespoke notebook goodies`
#     - http://github.com/tonybutzer/notebook   ##Kelcy
# 3. ### https://github.com/jupyter/jupyter/wiki/A-gallery-of-interesting-Jupyter-Notebooks
#     - ## I want to Live in Notebooks
#     - # That gallery has some nice clean examples
#     - https://nbviewer.jupyter.org/github/rossant/ipython-minibook/blob/master/chapter3/303-cities-data-explore.ipynb
# 4. Refelect on what you have learned
# 5. ### You don't have to learn everything - just remember where in EROS the Subject Matter Experts are
#
# ### IGM moment
#  - instant gratification monkey
#  - HPC stuff - hmm...
#  - ipython-books free online - this could democratize the eductaion system - that's good for us homeless folks with chromebooks
# ## https://github.com/ipython-books/cookbook-2nd/tree/master/chapter05_hpc
#
# ## All aboard the AWS express
# ![](https://m.media-amazon.com/images/I/71heub32ygL._AC_UL480_QL65_.jpg)
#
# ---
# ## I will be doing everything in Notebooks If I can -
#
# ---
# ## Neal - can you summarize or point to a few take aways so far on this AWS Journey
# - this section to be titled/called `Deep Thoughts` with Dr. Neal Pastick
# - your daily dose of prescriptive inspiration -
#     - eg. "Your friends are God's way of apologizing for your relatives"
#
# - `action NEAL` - send me a short description of your first DEEP LEARNING small project to be stood up in AWS - and we can start to define the inputs and the path to get them into an AWS bucket
#     - The downside of being student-of-the-month
#
#     - alternate: I can revisit some of the data pushes to the cloud we did for Steffi_ET - Nope lets use Kelcy.
# - ### aka THE STEFFINATOR
# <!--- Comments are Fun
# .. ![](https://www.tennisworldusa.org/imgb/79309/serena-williams-role-in-terminator-dark-fate.jpg) --->
# <img src="https://www.tennisworldusa.org/imgb/79309/serena-williams-role-in-terminator-dark-fate.jpg" width="20%">
#
# ---
#
# ## ... breaking news ... this just in ... Kelcy Smith gets credentialed ....
#
# - ### Kelcy shall teach a session on data pushing to the cloud - using
#     - aws s3 sync {local dir] s3://KELCYS-FAVORITE-BUCKET/SOME_LDCM_INPUT_DATA_PRE_PREFIX_PSEUDO_DIR
# ```
# aws s3 sync /lustre/data3/kelcy/myprecip s3://pangeo-bucket-kelcy/in/preciptation
# ```
#     - or even better using `rclone` from a docker container from `llsrlscd02`
#
# ---
#         - l is for landsat
#         - l is for lizard
#         - s is for server
#         - l is for linux
#         - s is for science
#         - d is for development
#         - 02 - there are at least 2 of these
#             - 2-two linux servers will do more good then 1529-one-thousand-five-hunded windows boxes
#         - there is a document on this somewhere
# ---
# ### rclone is the bomb! - rclone is your friend - like having a data-wrangler-robot
# - How about `rclone` in a `docker` container
#     - ABSOLUTELY!
#
# ---
# ![image.png](seneca-dare.PNG)
# ---
#
# ### People hate notebooks - but they somehow tolerate naming conventions like:
#
# #### IGSKMNCNLT01529
#
# - I is for Interior
# - GS is for Geological Survey
# - KM is for my friend Karl Mundt
# - NC is for National Center - not just regional - national - that's cause we were headed for world class
# - N - is for not here - this is an off-site dude - might even be one of those contractors -
#     - Star bellied sneetches had bellies with stars.
#     - Plain bellied sneeches had none upon thars.
#         - https://www.bethechangeconsulting.com/sites/default/files/worksheets/The-Sneetches.pdf
# - LT this is a Laptop - too bad its windows - nobody uses windows to do real work
# - 01529 - this means there's at least 1529 non-productive people out there
#
# ```
# (base) [klsmith@llsrlscd02 ~]$ aws s3 ls s3://chs-pangeo-data-bucket
#                            PRE dnowacki/
#                            PRE ebulliner/
#                            PRE ethoms/
#                            PRE jdornbierer/
#                            PRE jhensleigh/
#                            PRE jjwalker/
#                            PRE kweber/
#                            PRE mcushing/
#                            PRE mmartini/
#                            PRE rsignell/
#                            PRE scongdon/
# 2020-03-11 10:54:40       2384 s3bucket.yml
# ```
#
# ![](seneca-need.PNG)
# ---
# ### Kelcy - will show how to open a terminal and clone the notebook repo - placing it in an `opt` subdirectory
# - git clone http://github.com/tonybutzer/notebook
# - crude instructions below
#
# # Then questions
#
# # Then what else is new - more notebooks
#
# <img src="https://opendreamkit.org/public/images/jupyterhub.png" width="20%">
#
# - death by notebooks - what a way to go!
# - back when they let tony have staff - he had a tech writer - i think his spelling, grammar and punctuation have gotten so much better - now :-)  -- :O)
#
# ## References
# https://www.dataquest.io/blog/jupyter-notebook-tutorial/

# %%
#! wget https://raw.githubusercontent.com/ipython-books/minibook-code/master/chapter3/303-cities-data-explore.ipynb
# Out:
# --2020-12-05 10:42:14--  https://raw.githubusercontent.com/ipython-books/minibook-code/master/chapter3/303-cities-data-explore.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.52.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.52.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20791 (20K) [text/plain]
# Saving to: ‘303-cities-data-explore.ipynb.1’
#
# 303-cities-data-exp 100%[===================>]  20.30K  --.-KB/s    in 0.001s
#
# 2020-12-05 10:42:15 (28.1 MB/s) - ‘303-cities-data-explore.ipynb.1’ saved [20791/20791]

# %% [markdown]
# # Signing into the jupyterhub-mini-pangeo
#
# - 10.12.69.233
#     - username is '[LASTNAME]'
#     - password is `harmony`
#
# ---
#
# # May have to make this site bigger ec2 instance - EC2 - we learned that term last week - i wasn't expecting more than 2 or 3 people to hang in there..
#
# ### Lastnames
# ```
# anthony
# ballu
# benedict
# boyte
# bunde
# butzer
# dahal
# danielson
# holen
# mainali
# mcelhone
# oimoen
# pastick
# postma
# rigge
# rover
# schoen
# shrestha
# smith
# sun
# wylie
# young
# zhou
#
# ```
#
# # git repo clone
#
# - clone our notebook repo
# - next week we will do a `git pull` for updates
#
# ## Instructions
#
# - ## open a terminal in jupyter
#     - find Home Page - browser tab - or middle click jupyterhub above - tony to demo
#     - [new] button - terminal
#     - pwd ; ls;
# ---
# - ## mkdir opt
# - ### cd opt
# - # git clone http://github.com/tonybutzer/notebook

# %% [markdown]
# ```
# jupyter-butzer@ip-10-12-69-233:~$ mkdir opt
# jupyter-butzer@ip-10-12-69-233:~$ cd opt
# jupyter-butzer@ip-10-12-69-233:~/opt$ git clone http://github.com/tonybutzer/notebook
# Cloning into 'notebook'...
# warning: redirecting to https://github.com/tonybutzer/notebook/
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (162/162), done.
# remote: Total 1212 (delta 83), reused 146 (delta 37), pack-reused 1009
# Receiving objects: 100% (1212/1212), 341.87 MiB | 40.62 MiB/s, done.
# Resolving deltas: 100% (456/456), done.
# Checking out files: 100% (552/552), done.
# jupyter-butzer@ip-10-12-69-233:~/opt$ ls
# notebook
# jupyter-butzer@ip-10-12-69-233:~/opt$ ls -lR
# .:
# total 4
# drwxr-xr-x 6 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 notebook
#
# ./notebook:
# total 16
# drwxr-xr-x  4 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 00-Harmony
# drwxr-xr-x 18 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 01-Everything-but-harmony
# drwxr-xr-x  3 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 99-Viz-and-friends
# -rw-r--r--  1 jupyter-butzer jupyter-butzer  327 Dec  2 15:10 Makefile
#
# ./notebook/00-Harmony:
# total 8
# drwxr-xr-x 3 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 00-steffi-et
# drwxr-xr-x 2 jupyter-butzer jupyter-butzer 4096 Dec  2 15:10 01-neal-permafrost
#
# ./notebook/00-Harmony/00-steffi-et:
# total 7300
# -rw-r--r-- 1 jupyter-butzer jupyter-butzer 7467262 Dec  2 15:10 96-hvplot-experiment-image-annual-et-viewer-decorator-version.ipynb
# -rw-r--r-- 1 jupyter-butzer jupyter-butzer      16 Dec  2 15:10 Readme.md
# ```

# %% [markdown]
# - "I don't wanna live like this; but I don't wanna die"
#     - https://www.youtube.com/watch?v=yfGEq0JWxGM
