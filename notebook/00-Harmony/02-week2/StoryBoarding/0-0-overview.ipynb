# %% [markdown]
# # Secret Puzzel Puzzle
# - jumble word Puzzel
#
# - ## Your mini-pangeo awaits madam - just answer these questions three.
# - ### What is your favorite url?
# - # http://10.12.69.233
# - ### What is your lastname in lowercase?
# - # mine is butzer
# - ### how do you spell the word harmony -- all lowercase
# - # i spell it harmony -- most of the time anyway
#
# ---
# ---
# ---
# ---
# ---
#
# ## Clone Clone Clone - Clone - Clone Clone Clone
#
# ---
#
# <img src="https://dolly.roslin.ed.ac.uk/wp-content/uploads/2016/01/Dolly-and-surrogate-mother-768x915.jpg" width=10%>
#
# <img src="https://dolly.roslin.ed.ac.uk/wp-content/uploads/2016/01/Dolly-and-surrogate-mother-768x915.jpg" width=10%>
#
# ---
#
# - ### Open a Terminal
# - ## mkdir opt
# - ## cd opt
# - ## git clone http://github.com/tonybutzer/notebook
#
#
#
# - what is the airspeed velocity of an unladen swallow?

# %% [markdown]
# # Overview
#
# ## Approach
# > we will do a few small screen plays - to get us ready to interact with humans again post pandemic. I am starting to feel like the humans in the robot movie WALL-E.
#
# <img src=https://digitalpatmos.com/vol1issue1/wp-content/uploads/2017/11/BNL.jpg width="50%">
#
# ## Today
#
# 1. ### Get setup to use mini pangeo
# 2. ### go thru a few basic notebooks
# 3. ### wander around in notebook land
# 4. ### maybe look at just the ec2 t2.micro and what it can do
#
#
# ---
#
# ### The cloud space is full of options - you can personalize it and customize it just right for you
# ### How you use (and perhaps whether you use) notebooks is up to you
#
# ---
#
# ## Python is dead - long live Python
#
# # Python is both a joy and a curse
#
# - ##  when it works its amazing
# - ### when there is a bug - a stiff neck follows
# - ### everything in python is changing - mostly for the better - so you have to keep up
# - ### but then some things that used to work can break - did I mention you have to keep up
#
# ### stumbling into dependency hell is possible - docker can help
#
# ---
#
# python the language is easy to learn
#
# > its the rapidly growing package list - that is going to give you trouble
#
# - again both a blessing and a curse

# %%
#! pip install --user folium

# %%
! pip list
# Out:
# Package                Version
# ---------------------- -----------
# affine                 2.3.0
# aiobotocore            1.1.2
# aiohttp                3.7.3
# aioitertools           0.7.1
# alembic                1.4.3
# asn1crypto             0.24.0
# async-generator        1.10
# async-timeout          3.0.1
# attrs                  20.3.0
# awscli                 1.18.185
# backcall               0.2.0
# bleach                 3.2.1
# bokeh                  2.2.3
# boto3                  1.16.25
# botocore               1.19.25
# branca                 0.4.1
# Brotli                 1.0.9
# cached-property        1.5.2
# certifi                2020.11.8
# certipy                0.1.3
# cffi                   1.12.3
# chardet                3.0.4
# click                  7.1.2
# click-plugins          1.1.1
# cligj                  0.7.1
# cloudpickle            1.6.0
# colorama               0.4.3
# colorcet               2.0.2
# conda                  4.8.1
# ...
