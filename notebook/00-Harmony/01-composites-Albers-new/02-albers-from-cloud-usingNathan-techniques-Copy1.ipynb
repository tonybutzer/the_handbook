# %% [markdown]
# # Working with Landsat Data in the Amazon Web Services (AWS) Cloud
#
# This tutorial demonstrates how users discover Landsat Data stored within the AWS Cloud environment by searching SAT-API. Landsat data stored in the AWS Cloud is located within U.S. West (Oregon) us-west-2 region in a requester pays Simple Storage Services (S3) bucket. Users interested in utilizing direct access to Landsat data stored in S3 are encouraged to visit the Requester Pays Documentation Page (https://docs.aws.amazon.com/AmazonS3/latest/dev/RequesterPaysBuckets.html) for information concerning potential egress costs to accessing Landsat data with this method.
#
# <b>AWS Bucket Name:</b> usgs-landsat (Requester Pays) <br />
# <b>AWS Region:</b> US West (Oregon) us-west-2<br />
#
# An AWS account is required before undertaking this tutorial. Please see the AWS Account website to establish an account (https://aws.amazon.com/account/).  <br />

# %% [markdown]
# ### Search USGS Sat-API

# %%
import os
import sys
import json
import requests
import datetime
import itertools
import pandas as pd

sat_api_url = "https://landsatlook.usgs.gov/sat-api"

# %% [markdown]
# #### Request SAT-API Endpoint

# %%
satAPI = requests.post(sat_api_url)
if satAPI.status_code == 200:
    print('Sat-API is Available')
else:
    print('Sat-API is not Available')
    sys.exit()
# Out:
# Sat-API is Available

# %%
#Lets see what was returned by the endpont
print(json.dumps(satAPI.json(), indent=2))
# Out:
# {
#   "links": [
#     {
#       "href": "https://landsatlook.usgs.gov/sat-api",
#       "rel": "self"
#     },
#     {
#       "href": "https://landsatlook.usgs.gov/sat-api/collections",
#       "rel": "data"
#     },
#     {
#       "rel": "service"
#     }
#   ]
# }

# %%
#Lets look at the collections
satAPICollections = requests.post('https://landsatlook.usgs.gov/sat-api/collections')
print(json.dumps(satAPICollections.json(), indent=2))
# Out:
# {
#   "meta": {
#     "page": 1,
#     "limit": 100,
#     "found": 12,
#     "returned": 12
#   },
#   "collections": [
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c1l2alb-ta",
#       "title": "Landsat Collection 1 Level-2 Albers Top of Atmosphere (TA) Reflectance Product",
#       "description": "The Landsat Top of Atmosphere (TA) Reflectance product applies per pixel angle band corrections to the Level-1 radiance product.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "top of atmosphere reflectance"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c1l2alb-ta",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-ta"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-ta/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2alb-bt",
#       "title": "Landsat Collection 2 Level-2 Albers Top of Atmosphere Brightness Temperature (BT) Product",
#       "description": "The Landsat Top of Atmosphere Brightness Temperature (BT) product is a top of atmosphere product with radiance calculated 'at-sensor', not atmospherically corrected, and expressed in units of Kelvin.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "top of atmosphere brightness temperature"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2alb-bt",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-bt"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-bt/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2alb-ta",
#       "title": "Landsat Collection 2 Level-2 Albers Top of Atmosphere (TA) Reflectance Product",
#       "description": "The Landsat Top of Atmosphere (TA) Reflectance product applies per pixel angle band corrections to the Level-1 radiance product.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "top of atmosphere reflectance"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2alb-ta",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-ta"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-ta/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2alb-st",
#       "title": "Landsat Collection 2 Level-2 Albers Surface Temperature (ST) Product",
#       "description": "The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface temperature"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2alb-st",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-st"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-st/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c1l2alb-st",
#       "title": "Landsat Collection 1 Level-2 Albers Surface Temperature (ST) Product",
#       "description": "The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface temperature"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c1l2alb-st",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-st"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-st/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2-sr",
#       "title": "Landsat Collection 2 Level-2 UTM Surface Reflectance (SR) Product",
#       "description": "The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface reflectance"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2-sr",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2-st",
#       "title": "Landsat Collection 2 Level-2 UTM Surface Temperature (ST) Product",
#       "description": "The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface temperature"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2-st",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-st"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-st/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c1l1",
#       "title": "Landsat Collection 1 Level-1 Product",
#       "description": "The Landsat Level-1 product is a top of atmosphere product distributed as scaled and calibrated digital numbers.",
#       "keywords": [
#         "landsat",
#         "landsat 1",
#         "landsat 2",
#         "landsat 3",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1972-07-25",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c1l1",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 1",
#           "landsat 2",
#           "landsat 3",
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l1"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l1/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c1l2alb-bt",
#       "title": "Landsat Collection 1 Level-2 Albers Top of Atmosphere Brightness Temperature (BT) Product",
#       "description": "The Landsat Top of Atmosphere Brightness Temperature (BT) product is a top of atmosphere product with radiance calculated 'at-sensor', not atmospherically corrected, and expressed in units of Kelvin.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "top of atmosphere brightness temperature"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c1l2alb-bt",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-bt"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-bt/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c1l2alb-sr",
#       "title": "Landsat Collection 1 Level-2 Albers Surface Reflectance (SR) Product",
#       "description": "The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface reflectance"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c1l2alb-sr",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l1",
#       "title": "Landsat Collection 2 Level-1 Product",
#       "description": "The Landsat Level-1 product is a top of atmosphere product distributed as scaled and calibrated digital numbers.",
#       "keywords": [
#         "landsat",
#         "landsat 1",
#         "landsat 2",
#         "landsat 3",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1972-07-25",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l1",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 1",
#           "landsat 2",
#           "landsat 3",
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items"
#         }
#       ]
#     },
#     {
#       "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#       "id": "landsat-c2l2alb-sr",
#       "title": "Landsat Collection 2 Level-2 Albers Surface Reflectance (SR) Product",
#       "description": "The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.",
#       "keywords": [
#         "landsat",
#         "landsat 4",
#         "landsat 5",
#         "landsat 7",
#         "landsat 8",
#         "surface reflectance"
#       ],
#       "stac_version": "0.7.0",
#       "extent": {
#         "spatial": [
#           -180,
#           -90,
#           180,
#           90
#         ],
#         "temporal": [
#           "1982-08-22",
#           null
#         ]
#       },
#       "providers": [
#         {
#           "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#           "roles": [
#             "producer"
#           ],
#           "url": "https://eros.usgs.gov/"
#         }
#       ],
#       "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#       "properties": {
#         "collection": "landsat-c2l2alb-sr",
#         "eo:gsd": 30,
#         "eo:platform": [
#           "landsat 4",
#           "landsat 5",
#           "landsat 7",
#           "landsat 8"
#         ],
#         "eo:off_nadir": 0
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         },
#         {
#           "rel": "items",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr/items"
#         }
#       ]
#     }
#   ]
# }

# %%
sat_collections = satAPICollections.json()
my_df = pd.DataFrame(sat_collections['collections'])
my_df
# Out:
#                                                schema                  id  \
# 0   https://github.com/radiantearth/stac-spec/blob...  landsat-c1l2alb-ta
# 1   https://github.com/radiantearth/stac-spec/blob...  landsat-c2l2alb-bt
# 2   https://github.com/radiantearth/stac-spec/blob...  landsat-c2l2alb-ta
# 3   https://github.com/radiantearth/stac-spec/blob...  landsat-c2l2alb-st
# 4   https://github.com/radiantearth/stac-spec/blob...  landsat-c1l2alb-st
# 5   https://github.com/radiantearth/stac-spec/blob...     landsat-c2l2-sr
# 6   https://github.com/radiantearth/stac-spec/blob...     landsat-c2l2-st
# 7   https://github.com/radiantearth/stac-spec/blob...        landsat-c1l1
# 8   https://github.com/radiantearth/stac-spec/blob...  landsat-c1l2alb-bt
# 9   https://github.com/radiantearth/stac-spec/blob...  landsat-c1l2alb-sr
# 10  https://github.com/radiantearth/stac-spec/blob...        landsat-c2l1
# 11  https://github.com/radiantearth/stac-spec/blob...  landsat-c2l2alb-sr
#
#                                                 title  \
# 0   Landsat Collection 1 Level-2 Albers Top of Atm...
# 1   Landsat Collection 2 Level-2 Albers Top of Atm...
# 2   Landsat Collection 2 Level-2 Albers Top of Atm...
# 3   Landsat Collection 2 Level-2 Albers Surface Te...
# 4   Landsat Collection 1 Level-2 Albers Surface Te...
# 5   Landsat Collection 2 Level-2 UTM Surface Refle...
# 6   Landsat Collection 2 Level-2 UTM Surface Tempe...
# 7                Landsat Collection 1 Level-1 Product
# 8   Landsat Collection 1 Level-2 Albers Top of Atm...
# 9   Landsat Collection 1 Level-2 Albers Surface Re...
# 10               Landsat Collection 2 Level-1 Product
# 11  Landsat Collection 2 Level-2 Albers Surface Re...
#
#                                           description  \
# 0   The Landsat Top of Atmosphere (TA) Reflectance...
# 1   The Landsat Top of Atmosphere Brightness Tempe...
# 2   The Landsat Top of Atmosphere (TA) Reflectance...
# 3   The Landsat Surface Temperature (ST) product r...
# 4   The Landsat Surface Temperature (ST) product r...
# 5   The Landsat Surface Reflectance (SR) product m...
# 6   The Landsat Surface Temperature (ST) product r...
# 7   The Landsat Level-1 product is a top of atmosp...
# 8   The Landsat Top of Atmosphere Brightness Tempe...
# 9   The Landsat Surface Reflectance (SR) product m...
# 10  The Landsat Level-1 product is a top of atmosp...
# 11  The Landsat Surface Reflectance (SR) product m...
#
#                                              keywords stac_version  \
# 0   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 1   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 2   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 3   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 4   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 5   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 6   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 7   [landsat, landsat 1, landsat 2, landsat 3, lan...        0.7.0
# 8   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 9   [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
# 10  [landsat, landsat 1, landsat 2, landsat 3, lan...        0.7.0
# 11  [landsat, landsat 4, landsat 5, landsat 7, lan...        0.7.0
#
#                                                extent  \
# 0   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 1   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 2   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 3   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 4   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 5   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 6   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 7   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 8   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 9   {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 10  {'spatial': [-180, -90, 180, 90], 'temporal': ...
# 11  {'spatial': [-180, -90, 180, 90], 'temporal': ...
#
#                                             providers  \
# 0   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 1   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 2   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 3   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 4   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 5   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 6   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 7   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 8   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 9   [{'name': 'U.S. Geological Survey (USGS) Earth...
# 10  [{'name': 'U.S. Geological Survey (USGS) Earth...
# 11  [{'name': 'U.S. Geological Survey (USGS) Earth...
#
#                                               license  \
# 0   In accordance with OMB Circular A-130 and the ...
# 1   In accordance with OMB Circular A-130 and the ...
# 2   In accordance with OMB Circular A-130 and the ...
# 3   In accordance with OMB Circular A-130 and the ...
# 4   In accordance with OMB Circular A-130 and the ...
# 5   In accordance with OMB Circular A-130 and the ...
# 6   In accordance with OMB Circular A-130 and the ...
# 7   In accordance with OMB Circular A-130 and the ...
# 8   In accordance with OMB Circular A-130 and the ...
# 9   In accordance with OMB Circular A-130 and the ...
# 10  In accordance with OMB Circular A-130 and the ...
# 11  In accordance with OMB Circular A-130 and the ...
#
#                                            properties  \
# 0   {'collection': 'landsat-c1l2alb-ta', 'eo:gsd':...
# 1   {'collection': 'landsat-c2l2alb-bt', 'eo:gsd':...
# 2   {'collection': 'landsat-c2l2alb-ta', 'eo:gsd':...
# 3   {'collection': 'landsat-c2l2alb-st', 'eo:gsd':...
# 4   {'collection': 'landsat-c1l2alb-st', 'eo:gsd':...
# 5   {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30...
# 6   {'collection': 'landsat-c2l2-st', 'eo:gsd': 30...
# 7   {'collection': 'landsat-c1l1', 'eo:gsd': 30, '...
# 8   {'collection': 'landsat-c1l2alb-bt', 'eo:gsd':...
# 9   {'collection': 'landsat-c1l2alb-sr', 'eo:gsd':...
# 10  {'collection': 'landsat-c2l1', 'eo:gsd': 30, '...
# 11  {'collection': 'landsat-c2l2alb-sr', 'eo:gsd':...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'https://landsatlook....
# 1   [{'rel': 'self', 'href': 'https://landsatlook....
# 2   [{'rel': 'self', 'href': 'https://landsatlook....
# 3   [{'rel': 'self', 'href': 'https://landsatlook....
# 4   [{'rel': 'self', 'href': 'https://landsatlook....
# 5   [{'rel': 'self', 'href': 'https://landsatlook....
# 6   [{'rel': 'self', 'href': 'https://landsatlook....
# 7   [{'rel': 'self', 'href': 'https://landsatlook....
# 8   [{'rel': 'self', 'href': 'https://landsatlook....
# 9   [{'rel': 'self', 'href': 'https://landsatlook....
# 10  [{'rel': 'self', 'href': 'https://landsatlook....
# 11  [{'rel': 'self', 'href': 'https://landsatlook....

# %%
s_df = my_df[['id','title','description']]
pd.set_option('display.max_colwidth', -1)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
s_df
# Out:
#                     id  \
# 0   landsat-c1l2alb-ta
# 1   landsat-c2l2alb-bt
# 2   landsat-c2l2alb-ta
# 3   landsat-c2l2alb-st
# 4   landsat-c1l2alb-st
# 5   landsat-c2l2-sr
# 6   landsat-c2l2-st
# 7   landsat-c1l1
# 8   landsat-c1l2alb-bt
# 9   landsat-c1l2alb-sr
# 10  landsat-c2l1
# 11  landsat-c2l2alb-sr
#
#                                                                                         title  \
# 0   Landsat Collection 1 Level-2 Albers Top of Atmosphere (TA) Reflectance Product
# 1   Landsat Collection 2 Level-2 Albers Top of Atmosphere Brightness Temperature (BT) Product
# 2   Landsat Collection 2 Level-2 Albers Top of Atmosphere (TA) Reflectance Product
# 3   Landsat Collection 2 Level-2 Albers Surface Temperature (ST) Product
# 4   Landsat Collection 1 Level-2 Albers Surface Temperature (ST) Product
# 5   Landsat Collection 2 Level-2 UTM Surface Reflectance (SR) Product
# 6   Landsat Collection 2 Level-2 UTM Surface Temperature (ST) Product
# 7   Landsat Collection 1 Level-1 Product
# 8   Landsat Collection 1 Level-2 Albers Top of Atmosphere Brightness Temperature (BT) Product
# 9   Landsat Collection 1 Level-2 Albers Surface Reflectance (SR) Product
# 10  Landsat Collection 2 Level-1 Product
# 11  Landsat Collection 2 Level-2 Albers Surface Reflectance (SR) Product
#
#                                                                                                                                                                                                 description
# 0   The Landsat Top of Atmosphere (TA) Reflectance product applies per pixel angle band corrections to the Level-1 radiance product.
# 1   The Landsat Top of Atmosphere Brightness Temperature (BT) product is a top of atmosphere product with radiance calculated 'at-sensor', not atmospherically corrected, and expressed in units of Kelvin.
# 2   The Landsat Top of Atmosphere (TA) Reflectance product applies per pixel angle band corrections to the Level-1 radiance product.
# 3   The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).
# 4   The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).
# 5   The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.
# 6   The Landsat Surface Temperature (ST) product represents the temperature of the Earth's surface in Kelvin (K).
# 7   The Landsat Level-1 product is a top of atmosphere product distributed as scaled and calibrated digital numbers.
# 8   The Landsat Top of Atmosphere Brightness Temperature (BT) product is a top of atmosphere product with radiance calculated 'at-sensor', not atmospherically corrected, and expressed in units of Kelvin.
# 9   The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.
# 10  The Landsat Level-1 product is a top of atmosphere product distributed as scaled and calibrated digital numbers.
# 11  The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.

# %% [markdown]
# # EXPERIMENT with the albers stuff
#
# ## Landsat Collection 1 Level-2 Albers Surface Reflectance (SR) Product

# %%
s_df.to_csv('collection_descriptions.csv')

# %%
dir(s_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_numeric_operations',
#  '_add_series_or_dataframe_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_aggregate',
#  '_aggregate_multiple_funcs',
#  '_align_frame',
#  '_align_series',
#  '_box_col_values',
#  '_builtin_table',
#  '_can_fast_transpose',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_cython_table',
#  '_data',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_from_arrays',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_cython_func',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_builtin_func',
#  '_is_cached',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iter_column_arrays',
#  '_ix',
#  '_ixs',
#  '_join_compat',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_needs_reindex_multi',
#  '_obj_with_exclusions',
#  '_protect_consolidate',
#  '_reduce',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_selected_obj',
#  '_selection',
#  '_selection_list',
#  '_selection_name',
#  '_series',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_is_copy',
#  '_set_item',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_try_aggregate_string_function',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'description',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'id',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'title',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
#lets look at the landsat-c1l2alb-sr 	collection
c2L2SR = requests.post('https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr')
print(json.dumps(c2L2SR.json(), indent=2))
# Out:
# {
#   "schema": "https://github.com/radiantearth/stac-spec/blob/v0.7.0/collection-spec/json-schema/collection.json",
#   "id": "landsat-c1l2alb-sr",
#   "title": "Landsat Collection 1 Level-2 Albers Surface Reflectance (SR) Product",
#   "description": "The Landsat Surface Reflectance (SR) product measures the fraction of incoming solar radiation that is reflected from Earth's surface to the Landsat sensor.",
#   "keywords": [
#     "landsat",
#     "landsat 4",
#     "landsat 5",
#     "landsat 7",
#     "landsat 8",
#     "surface reflectance"
#   ],
#   "stac_version": "0.7.0",
#   "extent": {
#     "spatial": [
#       -180,
#       -90,
#       180,
#       90
#     ],
#     "temporal": [
#       "1982-08-22",
#       null
#     ]
#   },
#   "providers": [
#     {
#       "name": "U.S. Geological Survey (USGS) Earth Resources Observation and Science (EROS) Center",
#       "roles": [
#         "producer"
#       ],
#       "url": "https://eros.usgs.gov/"
#     }
#   ],
#   "license": "In accordance with OMB Circular A-130 and the USGS Data Policy, the USGS provides non-discriminatory, unrestricted access to the National Satellite Land Remote Sensing Data Archive (NSLRSDA), which includes Landsat.",
#   "properties": {
#     "collection": "landsat-c1l2alb-sr",
#     "eo:gsd": 30,
#     "eo:platform": [
#       "landsat 4",
#       "landsat 5",
#       "landsat 7",
#       "landsat 8"
#     ],
#     "eo:off_nadir": 0
#   },
#   "links": [
#     {
#       "rel": "self",
#       "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr"
#     },
#     {
#       "rel": "parent",
#       "href": "https://landsatlook.usgs.gov/sat-api/stac"
#     },
#     {
#       "rel": "root",
#       "href": "https://landsatlook.usgs.gov/sat-api/stac"
#     },
#     {
#       "rel": "items",
#       "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr/items"
#     }
#   ]
# }

# %% [markdown]
# # No luck random selection of albers collectio-1 surface reflectance

# %%
#lets pick a random product in the landsat-c2l2-sr Collection and look at the STAC Metadata
srProduct = requests.post ('https://landsatlook.usgs.gov/sat-api/collections/landsat-c1l2alb-sr/items')
print(json.dumps(srProduct.json()))
# print(json.dumps(srProduct.json()['features'][1]['geometry'], indent=2))
# Out:
# {"type": "FeatureCollection", "meta": {"page": 1, "limit": 10, "found": 0, "returned": 0}, "features": [], "links": []}

# %% [markdown]
# # Look at albers collection-2

# %%
#landsat-c2l2alb-sr
srProduct = requests.post ('https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr/items')
#print(json.dumps(srProduct.json()))
print(json.dumps(srProduct.json()['features'][1]['geometry'], indent=2))
# Out:
# {
#   "type": "Polygon",
#   "coordinates": [
#     [
#       [
#         -84.5225816543082,
#         42.81182619609843
#       ],
#       [
#         -82.3150182365257,
#         42.40751831869339
#       ],
#       [
#         -82.90892119348004,
#         40.695333334324786
#       ],
#       [
#         -85.05783508876976,
#         41.09689287364745
#       ],
#       [
#         -84.5225816543082,
#         42.81182619609843
#       ]
#     ]
#   ]
# }

# %%
print(json.dumps(srProduct.json(), indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "meta": {
#     "page": 1,
#     "limit": 10,
#     "found": 11490,
#     "returned": 10
#   },
#   "features": [
#     {
#       "stac_version": "0.7.0",
#       "stac_extensions": [
#         "eo",
#         "https://landsat.usgs.gov/stac/landsat-extension/schema.json"
#       ],
#       "id": "LC08_L2SP_037029_20201214_20201219_02_A1",
#       "type": "Feature",
#       "bbox": [
#         -110.41555462673145,
#         43.54077775703913,
#         -107.53317410754619,
#         45.66323956363511
#       ],
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -109.84219477367219,
#               45.66323956363511
#             ],
#             [
#               -107.53317410754619,
#               45.24772099127874
#             ],
#             [
#               -108.17485655809486,
#               43.54077775703913
#             ],
#             [
#               -110.41555462673145,
#               43.95235578633179
#             ],
#             [
#               -109.84219477367219,
#               45.66323956363511
#             ]
#           ]
#         ]
#       },
#       "description": "Landsat Collection 2 Level-2 Surface Reflectance Product",
#       "properties": {
#         "collection": "landsat-c2l2alb-bt",
#         "eo:gsd": 30,
#         "eo:platform": "LANDSAT_8",
#         "eo:off_nadir": 0,
#         "datetime": "2020-12-14",
#         "eo:cloud_cover": 99.94,
#         "eo:sun_azimuth": 162.93642637,
#         "eo:sun_elevation": 20.28002615,
#         "eo:instrument": "OLI_TIRS",
#         "landsat:cloud_cover_land": 99.94,
#         "landsat:wrs_type": "2",
#         "landsat:wrs_path": "037",
#         "landsat:wrs_row": "029",
#         "landsat:scene_id": "LC80370292020349LGN00",
#         "landsat:collection_category": "A1",
#         "landsat:collection_number": "02",
#         "eo:bands": [
#           {
#             "center_wavelength": 0.44,
#             "name": "SR_B1",
#             "gsd": 30,
#             "common_name": "coastal"
#           },
#           {
#             "center_wavelength": 0.48,
#             "name": "SR_B2",
#             "gsd": 30,
#             "common_name": "blue"
#           },
#           {
#             "center_wavelength": 0.56,
#             "name": "SR_B3",
#             "gsd": 30,
#             "common_name": "green"
#           },
#           {
#             "center_wavelength": 0.65,
#             "name": "SR_B4",
#             "gsd": 30,
#             "common_name": "red"
#           },
#           {
#             "center_wavelength": 0.86,
#             "name": "SR_B5",
#             "gsd": 30,
#             "common_name": "nir08"
#           },
#           {
#             "center_wavelength": 1.6,
#             "name": "SR_B6",
#             "gsd": 30,
#             "common_name": "swir16"
#           },
#           {
#             "center_wavelength": 2.2,
#             "name": "SR_B7",
#             "gsd": 30,
#             "common_name": "swir22"
#           }
#         ]
#       },
#       "assets": {
#         "thumbnail": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_thumb_small.jpeg",
#           "title": "Thumbnail image",
#           "type": "image/jpeg"
#         },
#         "reduced_resolution_browse": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_thumb_large.jpeg",
#           "title": "Reduced resolution browse image",
#           "type": "image/jpeg"
#         },
#         "index": {
#           "href": "https://landsatlook.usgs.gov/stac-browser/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1",
#           "title": "HTML index page",
#           "type": "text/html"
#         },
#         "ST_B10.TIF": {
#           "title": "Surface Temperature Band",
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "eo:bands": [
#             0
#           ],
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_B10.TIF"
#         },
#         "ST_ATRAN.TIF": {
#           "title": "Atmospheric Transmittance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Atmospheric Transmittance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_ATRAN.TIF"
#         },
#         "ST_CDIST.TIF": {
#           "title": "Cloud Distance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Cloud Distance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_CDIST.TIF"
#         },
#         "ST_DRAD.TIF": {
#           "title": "Downwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Downwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_DRAD.TIF"
#         },
#         "ST_URAD.TIF": {
#           "title": "Upwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Upwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_URAD.TIF"
#         },
#         "ST_TRAD.TIF": {
#           "title": "Thermal Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Thermal Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_TRAD.TIF"
#         },
#         "ST_EMIS.TIF": {
#           "title": "Emissivity Band",
#           "description": "Landsat Collection 2 Level-2 Emissivity Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_EMIS.TIF"
#         },
#         "ST_EMSD.TIF": {
#           "title": "Emissivity Standard Deviation Band",
#           "description": "Landsat Collection 2 Level-2 Albers Emissivity Standard Deviation Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_EMSD.TIF"
#         },
#         "ST_QA.TIF": {
#           "title": "Surface Temperature Quality Assessment Band",
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ST_QA.TIF"
#         },
#         "ANG.txt": {
#           "title": "Angle Coefficients File",
#           "description": "Collection 2 Level-2 Albers Angle Coefficients File (ANG) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_ANG.txt"
#         },
#         "MTL.txt": {
#           "title": "Product Metadata File",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (MTL) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_MTL.txt"
#         },
#         "MTL.xml": {
#           "title": "Product Metadata File (xml)",
#           "description": "Collection 2 Level-1 Product Metadata File (xml) Surface Reflectance",
#           "type": "application/xml",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_MTL.xml"
#         },
#         "MTL.json": {
#           "title": "Product Metadata File (json)",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (json) Surface Reflectance",
#           "type": "application/json",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_MTL.json"
#         },
#         "QA_PIXEL.TIF": {
#           "title": "Pixel Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Pixel Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_QA_PIXEL.TIF"
#         },
#         "QA_RADSAT.TIF": {
#           "title": "Radiometric Saturation Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Radiometric Saturation Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_QA_RADSAT.TIF"
#         },
#         "TOA_B7.TIF": {
#           "eo:bands": [
#             6
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B2) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B2.TIF",
#           "title": "Blue Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B4) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B4.TIF",
#           "title": "Red Band (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B6.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B6) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B6.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B6)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B3) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B3.TIF",
#           "title": "Green Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Coastal/Aerosol Band (B1) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B1.TIF",
#           "title": "Coastal/Aerosol Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B5) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B5.TIF",
#           "title": "Near Infrared Band 0.8 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B9.TIF": {
#           "eo:bands": [
#             7
#           ],
#           "description": "Collection 2 Level-2 Albers Cirrus Band (B9) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_TOA_B9.TIF",
#           "title": "Cirrus Band (B9)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "BT_B10.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Thermal Infrared Band 10.9 (B10) Top of Atmosphere Brightness Temperature",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_BT_B10.TIF",
#           "title": "Thermal Infrared Band 10.9 (B10)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "BT_B11.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Thermal Infrared Band 10.9 (B11) Top of Atmosphere Brightness Temperature",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_BT_B11.TIF",
#           "title": "Thermal Infrared Band 12.0 (B11)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B2) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF",
#           "title": "Blue Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B7.TIF": {
#           "eo:bands": [
#             6
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B4) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B4.TIF",
#           "title": "Red Band (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B3) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B3.TIF",
#           "title": "Green Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B5) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B5.TIF",
#           "title": "Near Infrared Band 0.8 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_QA_AEROSOL.TIF": {
#           "description": "Collection 2 Level-2 Albers Aerosol Quality Analysis Band (ANG) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_QA_AEROSOL.TIF",
#           "title": "Aerosol Quality Analysis Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B6.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B6) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B6.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B6)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Coastal/Aerosol Band (B1) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B1.TIF",
#           "title": "Coastal/Aerosol Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         }
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr/items/LC08_L2SP_037029_20201214_20201219_02_A1"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "collection",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         }
#       ],
#       "collection": "landsat-c2l2alb-sr"
#     },
#     {
#       "stac_version": "0.7.0",
#       "stac_extensions": [
#         "eo",
#         "https://landsat.usgs.gov/stac/landsat-extension/schema.json"
#       ],
#       "id": "LC08_L2SP_020031_20201207_20201219_02_A2",
#       "type": "Feature",
#       "bbox": [
#         -85.05783508876976,
#         40.695333334324786,
#         -82.3150182365257,
#         42.81182619609843
#       ],
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -84.5225816543082,
#               42.81182619609843
#             ],
#             [
#               -82.3150182365257,
#               42.40751831869339
#             ],
#             [
#               -82.90892119348004,
#               40.695333334324786
#             ],
#             [
#               -85.05783508876976,
#               41.09689287364745
#             ],
#             [
#               -84.5225816543082,
#               42.81182619609843
#             ]
#           ]
#         ]
#       },
#       "description": "Landsat Collection 2 Level-2 Surface Reflectance Product",
#       "properties": {
#         "collection": "landsat-c2l2alb-ta",
#         "eo:gsd": 30,
#         "eo:platform": "LANDSAT_8",
#         "eo:off_nadir": 0,
#         "datetime": "2020-12-07",
#         "eo:cloud_cover": 99.96,
#         "eo:sun_azimuth": 162.493879,
#         "eo:sun_elevation": 23.55333631,
#         "eo:instrument": "OLI_TIRS",
#         "landsat:cloud_cover_land": 99.97,
#         "landsat:wrs_type": "2",
#         "landsat:wrs_path": "020",
#         "landsat:wrs_row": "031",
#         "landsat:scene_id": "LC80200312020342LGN00",
#         "landsat:collection_category": "A2",
#         "landsat:collection_number": "02",
#         "eo:bands": [
#           {
#             "center_wavelength": 0.44,
#             "name": "SR_B1",
#             "gsd": 30,
#             "common_name": "coastal"
#           },
#           {
#             "center_wavelength": 0.48,
#             "name": "SR_B2",
#             "gsd": 30,
#             "common_name": "blue"
#           },
#           {
#             "center_wavelength": 0.56,
#             "name": "SR_B3",
#             "gsd": 30,
#             "common_name": "green"
#           },
#           {
#             "center_wavelength": 0.65,
#             "name": "SR_B4",
#             "gsd": 30,
#             "common_name": "red"
#           },
#           {
#             "center_wavelength": 0.86,
#             "name": "SR_B5",
#             "gsd": 30,
#             "common_name": "nir08"
#           },
#           {
#             "center_wavelength": 1.6,
#             "name": "SR_B6",
#             "gsd": 30,
#             "common_name": "swir16"
#           },
#           {
#             "center_wavelength": 2.2,
#             "name": "SR_B7",
#             "gsd": 30,
#             "common_name": "swir22"
#           }
#         ]
#       },
#       "assets": {
#         "thumbnail": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_thumb_small.jpeg",
#           "title": "Thumbnail image",
#           "type": "image/jpeg"
#         },
#         "reduced_resolution_browse": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_thumb_large.jpeg",
#           "title": "Reduced resolution browse image",
#           "type": "image/jpeg"
#         },
#         "index": {
#           "href": "https://landsatlook.usgs.gov/stac-browser/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2",
#           "title": "HTML index page",
#           "type": "text/html"
#         },
#         "BT_B10.TIF": {
#           "title": "Thermal Infrared Band 10.9 (B10)",
#           "description": "Collection 2 Level-2 Albers Thermal Infrared Band 10.9 (B10) Top of Atmosphere Brightness Temperature",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "eo:bands": [
#             0
#           ],
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_BT_B10.TIF"
#         },
#         "BT_B11.TIF": {
#           "title": "Thermal Infrared Band 12.0 (B11)",
#           "description": "Collection 2 Level-2 Albers Thermal Infrared Band 10.9 (B11) Top of Atmosphere Brightness Temperature",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "eo:bands": [
#             1
#           ],
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_BT_B11.TIF"
#         },
#         "ANG.txt": {
#           "title": "Angle Coefficients File",
#           "description": "Collection 2 Level-2 Albers Angle Coefficients File (ANG) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ANG.txt"
#         },
#         "MTL.txt": {
#           "title": "Product Metadata File",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (MTL) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_MTL.txt"
#         },
#         "MTL.xml": {
#           "title": "Product Metadata File (xml)",
#           "description": "Collection 2 Level-1 Product Metadata File (xml) Surface Reflectance",
#           "type": "application/xml",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_MTL.xml"
#         },
#         "MTL.json": {
#           "title": "Product Metadata File (json)",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (json) Surface Reflectance",
#           "type": "application/json",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_MTL.json"
#         },
#         "QA_PIXEL.TIF": {
#           "title": "Pixel Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Pixel Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_QA_PIXEL.TIF"
#         },
#         "QA_RADSAT.TIF": {
#           "title": "Radiometric Saturation Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Radiometric Saturation Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_QA_RADSAT.TIF"
#         },
#         "ST_DRAD.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Downwelled Radiance Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_DRAD.TIF",
#           "title": "Downwelled Radiance Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_B10.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_B10.TIF",
#           "title": "Surface Temperature Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_ATRAN.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Atmospheric Transmittance Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_ATRAN.TIF",
#           "title": "Atmospheric Transmittance Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_URAD.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Upwelled Radiance Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_URAD.TIF",
#           "title": "Upwelled Radiance Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_TRAD.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Thermal Radiance Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_TRAD.TIF",
#           "title": "Thermal Radiance Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_EMSD.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Emissivity Standard Deviation Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_EMSD.TIF",
#           "title": "Emissivity Standard Deviation Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_CDIST.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Cloud Distance Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_CDIST.TIF",
#           "title": "Cloud Distance Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_QA.TIF": {
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_QA.TIF",
#           "title": "Surface Temperature Quality Assessment Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "ST_EMIS.TIF": {
#           "description": "Landsat Collection 2 Level-2 Emissivity Band Surface Temperature Product",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_ST_EMIS.TIF",
#           "title": "Emissivity Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B7.TIF": {
#           "eo:bands": [
#             6
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B2) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B2.TIF",
#           "title": "Blue Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B4) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B4.TIF",
#           "title": "Red Band (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B6.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B6) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B6.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B6)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B3) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B3.TIF",
#           "title": "Green Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Coastal/Aerosol Band (B1) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B1.TIF",
#           "title": "Coastal/Aerosol Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B5) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B5.TIF",
#           "title": "Near Infrared Band 0.8 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B9.TIF": {
#           "eo:bands": [
#             7
#           ],
#           "description": "Collection 2 Level-2 Albers Cirrus Band (B9) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_TOA_B9.TIF",
#           "title": "Cirrus Band (B9)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B2) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B2.TIF",
#           "title": "Blue Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B7.TIF": {
#           "eo:bands": [
#             6
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B4) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B4.TIF",
#           "title": "Red Band (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B3) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B3.TIF",
#           "title": "Green Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B5) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B5.TIF",
#           "title": "Near Infrared Band 0.8 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_QA_AEROSOL.TIF": {
#           "description": "Collection 2 Level-2 Albers Aerosol Quality Analysis Band (ANG) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_QA_AEROSOL.TIF",
#           "title": "Aerosol Quality Analysis Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B6.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B6) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B6.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B6)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Coastal/Aerosol Band (B1) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/020/031/LC08_L2SP_020031_20201207_20201219_02_A2/LC08_L2SP_020031_20201207_20201219_02_A2_SR_B1.TIF",
#           "title": "Coastal/Aerosol Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         }
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr/items/LC08_L2SP_020031_20201207_20201219_02_A2"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "collection",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         }
#       ],
#       "collection": "landsat-c2l2alb-sr"
#     },
#     {
#       "stac_version": "0.7.0",
#       "stac_extensions": [
#         "eo",
#         "https://landsat.usgs.gov/stac/landsat-extension/schema.json"
#       ],
#       "id": "LC08_L2SP_022037_20201205_20201219_02_A1",
#       "type": "Feature",
#       "bbox": [
#         -90.56292848434867,
#         32.12085781945691,
#         -88.14419015080118,
#         34.22328876653094
#       ],
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -90.10868778643156,
#               34.22328876653094
#             ],
#             [
#               -88.14419015080118,
#               33.84441200630953
#             ],
#             [
#               -88.63758392535323,
#               32.12085781945691
#             ],
#             [
#               -90.56292848434867,
#               32.499179056325886
#             ],
#             [
#               -90.10868778643156,
#               34.22328876653094
#             ]
#           ]
#         ]
#       },
#       "description": "Landsat Collection 2 Level-2 Surface Reflectance Product",
#       "properties": {
#         "collection": "landsat-c2l2alb-bt",
#         "eo:gsd": 30,
#         "eo:platform": "LANDSAT_8",
#         "eo:off_nadir": 0,
#         "datetime": "2020-12-05",
#         "eo:cloud_cover": 0.01,
#         "eo:sun_azimuth": 159.18849073,
#         "eo:sun_elevation": 31.42093074,
#         "eo:instrument": "OLI_TIRS",
#         "landsat:cloud_cover_land": 0.01,
#         "landsat:wrs_type": "2",
#         "landsat:wrs_path": "022",
#         "landsat:wrs_row": "037",
#         "landsat:scene_id": "LC80220372020340LGN00",
#         "landsat:collection_category": "A1",
#         "landsat:collection_number": "02",
#         "eo:bands": [
#           {
#             "center_wavelength": 0.44,
#             "name": "SR_B1",
#             "gsd": 30,
#             "common_name": "coastal"
#           },
#           {
#             "center_wavelength": 0.48,
#             "name": "SR_B2",
#             "gsd": 30,
#             "common_name": "blue"
#           },
#           {
#             "center_wavelength": 0.56,
#             "name": "SR_B3",
#             "gsd": 30,
#             "common_name": "green"
#           },
#           {
#             "center_wavelength": 0.65,
#             "name": "SR_B4",
#             "gsd": 30,
#             "common_name": "red"
#           },
#           {
#             "center_wavelength": 0.86,
#             "name": "SR_B5",
#             "gsd": 30,
#             "common_name": "nir08"
#           },
#           {
#             "center_wavelength": 1.6,
#             "name": "SR_B6",
#             "gsd": 30,
#             "common_name": "swir16"
#           },
#           {
#             "center_wavelength": 2.2,
#             "name": "SR_B7",
#             "gsd": 30,
#             "common_name": "swir22"
#           }
#         ]
#       },
#       "assets": {
#         "thumbnail": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_thumb_small.jpeg",
#           "title": "Thumbnail image",
#           "type": "image/jpeg"
#         },
#         "reduced_resolution_browse": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_thumb_large.jpeg",
#           "title": "Reduced resolution browse image",
#           "type": "image/jpeg"
#         },
#         "index": {
#           "href": "https://landsatlook.usgs.gov/stac-browser/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1",
#           "title": "HTML index page",
#           "type": "text/html"
#         },
#         "ST_B10.TIF": {
#           "title": "Surface Temperature Band",
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "eo:bands": [
#             0
#           ],
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_B10.TIF"
#         },
#         "ST_ATRAN.TIF": {
#           "title": "Atmospheric Transmittance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Atmospheric Transmittance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_ATRAN.TIF"
#         },
#         "ST_CDIST.TIF": {
#           "title": "Cloud Distance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Cloud Distance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_CDIST.TIF"
#         },
#         "ST_DRAD.TIF": {
#           "title": "Downwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Downwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_DRAD.TIF"
#         },
#         "ST_URAD.TIF": {
#           "title": "Upwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Upwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_URAD.TIF"
#         },
#         "ST_TRAD.TIF": {
#           "title": "Thermal Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Thermal Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_TRAD.TIF"
#         },
#         "ST_EMIS.TIF": {
#           "title": "Emissivity Band",
#           "description": "Landsat Collection 2 Level-2 Emissivity Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_EMIS.TIF"
#         },
#         "ST_EMSD.TIF": {
#           "title": "Emissivity Standard Deviation Band",
#           "description": "Landsat Collection 2 Level-2 Albers Emissivity Standard Deviation Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/022/037/LC08_L2SP_022037_20201205_20201219_02_A1/LC08_L2SP_022037_20201205_20201219_02_A1_ST_EMSD.TIF"
#         },
#         "ST_QA.TIF": {
# ...
#             "name": "SR_B3",
#             "gsd": 30,
#             "common_name": "red"
#           },
#           {
#             "center_wavelength": 0.86,
#             "name": "SR_B4",
#             "gsd": 30,
#             "common_name": "nir08"
#           },
#           {
#             "center_wavelength": 1.6,
#             "name": "SR_B5",
#             "gsd": 30,
#             "common_name": "swir16"
#           },
#           {
#             "center_wavelength": 2.2,
#             "name": "SR_B7",
#             "gsd": 30,
#             "common_name": "swir22"
#           }
#         ]
#       },
#       "assets": {
#         "thumbnail": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_thumb_small.jpeg",
#           "title": "Thumbnail image",
#           "type": "image/jpeg"
#         },
#         "reduced_resolution_browse": {
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_thumb_large.jpeg",
#           "title": "Reduced resolution browse image",
#           "type": "image/jpeg"
#         },
#         "index": {
#           "href": "https://landsatlook.usgs.gov/stac-browser/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1",
#           "title": "HTML index page",
#           "type": "text/html"
#         },
#         "ST_ATRAN.TIF": {
#           "title": "Atmospheric Transmittance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Atmospheric Transmittance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_ATRAN.TIF"
#         },
#         "ST_CDIST.TIF": {
#           "title": "Cloud Distance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Cloud Distance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_CDIST.TIF"
#         },
#         "ST_DRAD.TIF": {
#           "title": "Downwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Downwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_DRAD.TIF"
#         },
#         "ST_URAD.TIF": {
#           "title": "Upwelled Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Upwelled Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_URAD.TIF"
#         },
#         "ST_TRAD.TIF": {
#           "title": "Thermal Radiance Band",
#           "description": "Landsat Collection 2 Level-2 Albers Thermal Radiance Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_TRAD.TIF"
#         },
#         "ST_EMIS.TIF": {
#           "title": "Emissivity Band",
#           "description": "Landsat Collection 2 Level-2 Albers Emissivity Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_EMIS.TIF"
#         },
#         "ST_EMSD.TIF": {
#           "title": "Emissivity Standard Deviation Band",
#           "description": "Landsat Collection 2 Level-2 Albers Emissivity Standard Deviation Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_EMSD.TIF"
#         },
#         "ST_QA.TIF": {
#           "title": "Surface Temperature Quality Assessment Band",
#           "description": "Landsat Collection 2 Level-2 Albers Surface Temperature Band Surface Temperature Product",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ST_QA.TIF"
#         },
#         "ANG.txt": {
#           "title": "Angle Coefficients File",
#           "description": "Collection 2 Level-2 Albers Angle Coefficients File (ANG) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_ANG.txt"
#         },
#         "MTL.txt": {
#           "title": "Product Metadata File",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (MTL) Surface Reflectance",
#           "type": "text/plain",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_MTL.txt"
#         },
#         "MTL.xml": {
#           "title": "Product Metadata File (xml)",
#           "description": "Collection 2 Level-1 Product Metadata File (xml) Surface Reflectance",
#           "type": "application/xml",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_MTL.xml"
#         },
#         "MTL.json": {
#           "title": "Product Metadata File (json)",
#           "description": "Collection 2 Level-2 Albers Product Metadata File (json) Surface Reflectance",
#           "type": "application/json",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_MTL.json"
#         },
#         "QA_PIXEL.TIF": {
#           "title": "Pixel Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Pixel Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_QA_PIXEL.TIF"
#         },
#         "QA_RADSAT.TIF": {
#           "title": "Radiometric Saturation Quality Assessment Band",
#           "description": "Collection 2 Level-2 Albers Radiometric Saturation Quality Assessment Band Surface Reflectance",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_QA_RADSAT.TIF"
#         },
#         "TOA_B7.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B2) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B2.TIF",
#           "title": "Green Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B4) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B4.TIF",
#           "title": "Near Infrared Band 0.8 (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B3) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B3.TIF",
#           "title": "Red Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B1) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B1.TIF",
#           "title": "Blue Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "TOA_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B5) Top of Atmosphere Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_TOA_B5.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "BT_B6.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Thermal Infrared Band 11.4 (B6) Top of Atmosphere Brightness Temperature",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_BT_B6.TIF",
#           "title": "Thermal Infrared Band 11.4 (B6)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B2.TIF": {
#           "eo:bands": [
#             1
#           ],
#           "description": "Collection 2 Level-2 Albers Green Band (B2) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B2.TIF",
#           "title": "Green Band (B2)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B7.TIF": {
#           "eo:bands": [
#             5
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 2.2 (B7) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B7.TIF",
#           "title": "Short-wave Infrared Band 2.2 (B7)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B4.TIF": {
#           "eo:bands": [
#             3
#           ],
#           "description": "Collection 2 Level-2 Albers Near Infrared Band 0.8 (B4) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B4.TIF",
#           "title": "Near Infrared Band 0.8 (B4)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_CLOUD_QA.TIF": {
#           "description": "Collection 2 Level-2 Albers Cloud Quality Opacity Band Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_CLOUD_QA.TIF",
#           "title": "Cloud Quality Analysis Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B3.TIF": {
#           "eo:bands": [
#             2
#           ],
#           "description": "Collection 2 Level-2 Albers Red Band (B3) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B3.TIF",
#           "title": "Red Band (B3)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B5.TIF": {
#           "eo:bands": [
#             4
#           ],
#           "description": "Collection 2 Level-2 Albers Short-wave Infrared Band 1.6 (B6) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B5.TIF",
#           "title": "Short-wave Infrared Band 1.6 (B5)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_ATMOS_OPACITY.TIF": {
#           "description": "Collection 2 Level-2 Albers Atmospheric Opacity Band Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_ATMOS_OPACITY.TIF",
#           "title": "Atmospheric Opacity Band",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         },
#         "SR_B1.TIF": {
#           "eo:bands": [
#             0
#           ],
#           "description": "Collection 2 Level-2 Albers Blue Band (B1) Surface Reflectance",
#           "href": "https://landsatlook.usgs.gov/data/collection02/level-2/albers/etm/2020/033/029/LE07_L2SP_033029_20201124_20201221_02_A1/LE07_L2SP_033029_20201124_20201221_02_A1_SR_B1.TIF",
#           "title": "BLue Band (B1)",
#           "type": "image/vnd.stac.geotiff; cloud-optimized=true"
#         }
#       },
#       "links": [
#         {
#           "rel": "self",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr/items/LE07_L2SP_033029_20201124_20201221_02_A1"
#         },
#         {
#           "rel": "parent",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "collection",
#           "href": "https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2alb-sr"
#         },
#         {
#           "rel": "root",
#           "href": "https://landsatlook.usgs.gov/sat-api/stac"
#         }
#       ],
#       "collection": "landsat-c2l2alb-sr"
#     }
#   ],
#   "links": [
#     {
#       "rel": "next",
#       "title": "Next page of results",
#       "href": "https://landsatlook.usgs.gov/sat-api/stac/search?query=%7B%22collections%22%3A%5B%22landsat-c2l2alb-sr%22%5D%7D&page=2&limit=10"
#     }
#   ]
# }

# %% [markdown]
# ### Setup a Sat-API Query

# %%
# This will handle pagination
def fetch_sat_api(query):
    headers = {
        "Content-Type": "application/json",
        "Accept-Encoding": "gzip",
        "Accept": "application/geo+json",
    }

    url = f"{sat_api_url}/stac/search"
    data = requests.post(url, headers=headers, json=query).json()
    error = data.get("message", "")
    if error:
        raise Exception(f"SAT-API failed and returned: {error}")

    meta = data.get("meta", {})
    if not meta.get("found"):
        return []
    print(meta)

    features = data["features"]
    if data["links"]:
        curr_page = int(meta["page"])
        query["page"] = curr_page + 1
        query["limit"] = meta["limit"]

        features = list(itertools.chain(features, fetch_sat_api(query)))

    return features

# %%
#set up query
#Find Scenes for Path 30, Row 28 in Collection 2 L2_SR Collection acquired between 1-January 1982 and 30-December 2019
#where scene cloud cover is between 0 and 30
min_cloud = 0
max_cloud = 30

date_min="1982-01-01"
date_max="2019-12-30"

start = datetime.datetime.strptime(date_min, "%Y-%m-%d").strftime("%Y-%m-%dT00:00:00Z")
end = datetime.datetime.strptime(date_max, "%Y-%m-%d").strftime("%Y-%m-%dT23:59:59Z")

query = {
    "time": f"{start}/{end}",
    "query": {
#         "landsat:wrs_path": {"in": ["30","030"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix
#         "landsat:wrs_row": {"in": ["28","028"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix"landsat:wrs_path": {"in": ["30","030"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix

        "landsat:wrs_path": {"in": ["37","037"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix
        "landsat:wrs_row": {"in": ["29","029"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix"landsat:wrs_path": {"in": ["30","030"]}, #landsat Path and Row are not 0 padded so that is a bug we will need to fix
        "eo:cloud_cover": {"gte": min_cloud, "lt": max_cloud},
        # "collection":{"eq": "landsat-c2l2-sr"}
        # "collection":{"eq": "landsat-c2l2alb-sr"}
    },
    "limit": 500 # We limit to 500 items per Page (requests) to make sure sat-api doesn't fail to return big features collection
}

features = fetch_sat_api(query)
# Out:
# {'page': 1, 'limit': 500, 'found': 1159, 'returned': 500}
# {'page': 2, 'limit': 500, 'found': 1159, 'returned': 500}
# {'page': 3, 'limit': 500, 'found': 1159, 'returned': 159}

# %%
t_df = pd.DataFrame(features)
t_df.head()
# Out:
#   stac_version  \
# 0  0.7.0
# 1  0.7.0
# 2  0.7.0
# 3  0.7.0
# 4  0.7.0
#
#                                                      stac_extensions  \
# 0  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 2  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 3  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 4  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
#
#                                          id     type  \
# 0  LE07_L2SP_037029_20191204_20200823_02_T1  Feature
# 1  LE07_L1TP_037029_20191204_20200823_02_T1  Feature
# 2  LE07_L1TP_037029_20191118_20200823_02_T1  Feature
# 3  LE07_L2SP_037029_20191118_20200823_02_T1  Feature
# 4  LC08_L2SP_037029_20191025_20200825_02_T1  Feature
#
#                                                                                 bbox  \
# 0  [-110.55406255962302, 43.65166498323397, -107.58689163184512, 45.592683921908666]
# 1  [-110.55406255962302, 43.65166498323397, -107.58689163184512, 45.592683921908666]
# 2  [-110.55405042250679, 43.65356270619706, -107.59022823338215, 45.59350700260609]
# 3  [-110.55405042250679, 43.65356270619706, -107.59022823338215, 45.59350700260609]
# 4  [-110.40820442513674, 43.54048896649301, -107.52545136101232, 45.66298835843279]
#
#                                                                                                                                                                                                                                                       geometry  \
# 0  {'type': 'Polygon', 'coordinates': [[[-110.02581389861015, 45.592683921908666], [-107.58689163184512, 45.23013688376147], [-108.18544354766571, 43.65166498323397], [-110.55406255962302, 43.996088054197166], [-110.02581389861015, 45.592683921908666]]]}
# 1  {'type': 'Polygon', 'coordinates': [[[-110.02581389861015, 45.592683921908666], [-107.58689163184512, 45.23013688376147], [-108.18544354766571, 43.65166498323397], [-110.55406255962302, 43.996088054197166], [-110.02581389861015, 45.592683921908666]]]}
# 2  {'type': 'Polygon', 'coordinates': [[[-110.02733817427033, 45.59350700260609], [-107.59022823338215, 45.23185696518918], [-108.18572685546617, 43.65356270619706], [-110.55405042250679, 43.99770863766861], [-110.02733817427033, 45.59350700260609]]]}
# 3  {'type': 'Polygon', 'coordinates': [[[-110.02733817427033, 45.59350700260609], [-107.59022823338215, 45.23185696518918], [-108.18572685546617, 43.65356270619706], [-110.55405042250679, 43.99770863766861], [-110.02733817427033, 45.59350700260609]]]}
# 4  {'type': 'Polygon', 'coordinates': [[[-109.83435316449669, 45.66298835843279], [-107.52545136101232, 45.2474556263086], [-108.16797488297027, 43.54048896649301], [-110.40820442513674, 43.95193863260952], [-109.83435316449669, 45.66298835843279]]]}
#
#                                                 description  \
# 0  Landsat Collection 2 Level-2 Surface Reflectance Product
# 1  Landsat Collection 2 Level-1 Product
# 2  Landsat Collection 2 Level-1 Product
# 3  Landsat Collection 2 Level-2 Surface Reflectance Product
# 4  Landsat Collection 2 Level-2 Surface Reflectance Product
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               properties  \
# 0  {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_7', 'eo:off_nadir': 0, 'datetime': '2019-12-04', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.41235073, 'eo:sun_elevation': 20.45497919, 'eo:instrument': 'ETM', 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019338EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
# 1  {'datetime': '2019-12-04', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.41235073, 'eo:sun_elevation': 20.45497919, 'eo:platform': 'LANDSAT_7', 'eo:instrument': 'ETM', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019338EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.49}, {'name': 'B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.66}, {'name': 'B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.84}, {'name': 'B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.65}, {'name': 'B6', 'common_name': 'tir', 'gsd': 30, 'center_wavelength': 11.45}, {'name': 'B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.22}, {'name': 'B8', 'common_name': 'pan', 'gsd': 30, 'center_wavelength': 0.71}]}
# 2  {'datetime': '2019-11-18', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.97114851, 'eo:sun_elevation': 23.69548072, 'eo:platform': 'LANDSAT_7', 'eo:instrument': 'ETM', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019322EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.49}, {'name': 'B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.66}, {'name': 'B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.84}, {'name': 'B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.65}, {'name': 'B6', 'common_name': 'tir', 'gsd': 30, 'center_wavelength': 11.45}, {'name': 'B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.22}, {'name': 'B8', 'common_name': 'pan', 'gsd': 30, 'center_wavelength': 0.71}]}
# 3  {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_7', 'eo:off_nadir': 0, 'datetime': '2019-11-18', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.97114851, 'eo:sun_elevation': 23.69548072, 'eo:instrument': 'ETM', 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019322EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
# 4  {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_8', 'eo:off_nadir': 0, 'datetime': '2019-10-25', 'eo:cloud_cover': 5.16, 'eo:sun_azimuth': 163.07242715, 'eo:sun_elevation': 31.67198614, 'eo:instrument': 'OLI_TIRS', 'landsat:cloud_cover_land': 5.16, 'landsat:wrs_type': '2', 'landsat:wrs_path': '37', 'landsat:wrs_row': '29', 'landsat:scene_id': 'LC80370292019298LGN00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'coastal', 'gsd': 30, 'center_wavelength': 0.44}, {'name': 'SR_B2', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B3', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B4', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B5', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B6', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  {'thumbnail': {'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_thumb_small.jpeg', 'title': 'Thumbnail image', 'type': 'image/jpeg'}, 'reduced_resolution_browse': {'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_thumb_large.jpeg', 'title': 'Reduced resolution browse image', 'type': 'image/jpeg'}, 'index': {'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1', 'title': 'HTML index page', 'type': 'text/html'}, 'SR_B1.TIF': {'title': 'BLue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [0], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_SR_B1.TIF'}, 'SR_B2.TIF': {'title': 'Green Band (B2)', 'description': 'Collection 2 Level-2 Green Band (B2) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [1], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_SR_B2.TIF'}, 'SR_B3.TIF': {'title': 'Red Band (B3)', 'description': 'Collection 2 Level-2 Red Band (B3) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [2], 'href': 'https://landsatlook
_T1_SR_B4.TIF'}, 'SR_B5.TIF': {'title': 'Near Infrared Band 0.8 (B5)', 'description': 'Collection 2 Level-2 Near Infrared Band 0.8 (B5) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [4], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2019/037/029/LC08_L2SP_037029_20191025_20200825_02_T1/LC08_L2SP_037029_20191025_20200825_02_T1_SR_B5.TIF'}, 'SR_B6.TIF': {'title': 'Short-wave Infrared Band 1.6 (B6)', 'description': 'Collection 2 Level-2 Short-wave Infrared Band 1.6 (B6) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [5], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2019/037/029/LC08_L2SP_037029_20191025_20200825_02_T1/LC08_L2SP_037029_20191025_20200825_02_T1_SR_B6.TIF'}, 'SR_B7.TIF': {'title': 'Short-wave Infrared Band 2.2 (B7)', 'description': 'Collection 2 Level-2 Short-wave Infrared Band 2.2 (B7) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [6], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2019/037/029/LC08_L2SP_037029_20191025_20200825_02_T1/LC08_L2SP_037029_20191025_20200825_02_T1_SR_B7.TIF'}, 'SR_QA_AEROSOL.TIF': {'title': 'Aerosol Quality Analysis Band', 'description': 'Collection 2 Level-2 Aerosol Quality Analysis Band (ANG) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/oli-tirs/2019/037/029/LC08_L2SP_037029_20191025_20200825_02_T1/LC08_L2SP_037029_20191025_20200825_02_T1_SR_QA_AEROSOL.TIF'}, 'ANG.txt': {'title': 'Angle Coefficients File', 'desc ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                   links  \
# 0  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LE07_L2SP_037029_20191204_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LE07_L1TP_037029_20191204_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 2  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LE07_L1TP_037029_20191118_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 3  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LE07_L2SP_037029_20191118_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 4  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LC08_L2SP_037029_20191025_20200825_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
#
#         collection
# 0  landsat-c2l2-sr
# 1  landsat-c2l1
# 2  landsat-c2l1
# 3  landsat-c2l2-sr
# 4  landsat-c2l2-sr

# %%
c_df = t_df[['collection']]
c_df
# Out:
#            collection
# 0     landsat-c2l2-sr
# 1     landsat-c2l1
# 2     landsat-c2l1
# 3     landsat-c2l2-sr
# 4     landsat-c2l2-sr
# ...               ...
# 1154  landsat-c2l1
# 1155  landsat-c2l1
# 1156  landsat-c2l1
# 1157  landsat-c2l1
# 1158  landsat-c2l1
#
# [1159 rows x 1 columns]

# %%
#Setup Table to show results
df = pd.DataFrame(features)
#Add Acqusition Dates
dates = []
for item in df['properties']:
    dates.append(item['datetime'])
#Add Product IDs
    ids = []
for item in df['id']:
    ids.append(item)
#Add Green Bands
#L8 has different band numbering for Green this accounts for that. Green = B3 L8 TM, ETM = B2
greens = []
for item in df['assets']:
    if 'Green' in item['SR_B3.TIF']['title']: 
        greens.append(item['SR_B3.TIF']['href'])
    else:
        greens.append(item['SR_B2.TIF']['href'])
#Add SWIR Bands 
#l8 SWIR Band = B6, L7 = B7, TM = B5 this accounts for that.
        swirs = []
for item in df['assets']:
    try:
        if 'Short-wave' in item['SR_B6.TIF']['title']:
            swirs.append(item['SR_B6.TIF']['href'])
    except:
        if 'Short-wave' in item['SR_B5.TIF']['title']:
            swirs.append(item['SR_B5.TIF']['href'])
#Combine into one table
ids = pd.DataFrame(ids, columns = ['Product ID'])
dates = pd.DataFrame(dates, columns = ['Date'])
greens = pd.DataFrame(greens, columns = ['Green'])
swirs = pd.DataFrame(swirs, columns = ['Swirs'])
df = pd.concat([ids, dates, greens, swirs], axis = 1, sort=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-a969a867ffdd> in <module>
#      13 greens = []
#      14 for item in df['assets']:
# ---> 15     if 'Green' in item['SR_B3.TIF']['title']:
#      16         greens.append(item['SR_B3.TIF']['href'])
#      17     else:
#
# KeyError: 'SR_B3.TIF'

# %%
#Display DF, object links are the cloudfront links which will re-direct to ERS to login need to convert these to S3 object links
df
# Out:
#      stac_version  \
# 0     0.7.0
# 1     0.7.0
# 2     0.7.0
# 3     0.7.0
# 4     0.7.0
# ...     ...
# 1154  0.7.0
# 1155  0.7.0
# 1156  0.7.0
# 1157  0.7.0
# 1158  0.7.0
#
#                                                         stac_extensions  \
# 0     [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1     [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 2     [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 3     [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 4     [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# ...                                                                 ...
# 1154  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1155  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1156  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1157  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
# 1158  [eo, https://landsat.usgs.gov/stac/landsat-extension/schema.json]
#
#                                             id     type  \
# 0     LE07_L2SP_037029_20191204_20200823_02_T1  Feature
# 1     LE07_L1TP_037029_20191204_20200823_02_T1  Feature
# 2     LE07_L1TP_037029_20191118_20200823_02_T1  Feature
# 3     LE07_L2SP_037029_20191118_20200823_02_T1  Feature
# 4     LC08_L2SP_037029_20191025_20200825_02_T1  Feature
# ...                                        ...      ...
# 1154  LM04_L1TP_037029_19830115_20200904_02_T2  Feature
# 1155  LM03_L1GS_037029_19821016_20200904_02_T2  Feature
# 1156  LM04_L1TP_037029_19821011_20200904_02_T2  Feature
# 1157  LM04_L1GS_037029_19820824_20200904_02_T2  Feature
# 1158  LM03_L1TP_037029_19820314_20200904_02_T2  Feature
#
#                                                                                     bbox  \
# 0     [-110.55406255962302, 43.65166498323397, -107.58689163184512, 45.592683921908666]
# 1     [-110.55406255962302, 43.65166498323397, -107.58689163184512, 45.592683921908666]
# 2     [-110.55405042250679, 43.65356270619706, -107.59022823338215, 45.59350700260609]
# 3     [-110.55405042250679, 43.65356270619706, -107.59022823338215, 45.59350700260609]
# 4     [-110.40820442513674, 43.54048896649301, -107.52545136101232, 45.66298835843279]
# ...                                                                                ...
# 1154  [-110.4003067288781, 43.68287532758569, -107.56673331594429, 45.57738926925389]
# 1155  [-106.38717603080704, 43.4945396421772, -103.45924463301785, 45.486800436111416]
# 1156  [-110.35695326077644, 43.674872187667994, -107.52486449414823, 45.578029016639796]
# 1157  [-110.24810506543247, 43.74317059138752, -107.58457756504801, 45.497544317593245]
# 1158  [-106.25733452788826, 43.504592757751944, -103.42958253814541, 45.363051790354156]
#
#                                                                                                                                                                                                                                                          geometry  \
# 0     {'type': 'Polygon', 'coordinates': [[[-110.02581389861015, 45.592683921908666], [-107.58689163184512, 45.23013688376147], [-108.18544354766571, 43.65166498323397], [-110.55406255962302, 43.996088054197166], [-110.02581389861015, 45.592683921908666]]]}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  properties  \
# 0     {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_7', 'eo:off_nadir': 0, 'datetime': '2019-12-04', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.41235073, 'eo:sun_elevation': 20.45497919, 'eo:instrument': 'ETM', 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019338EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
# 1     {'datetime': '2019-12-04', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.41235073, 'eo:sun_elevation': 20.45497919, 'eo:platform': 'LANDSAT_7', 'eo:instrument': 'ETM', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019338EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.49}, {'name': 'B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.66}, {'name': 'B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.84}, {'name': 'B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.65}, {'name': 'B6', 'common_name': 'tir', 'gsd': 30, 'center_wavelength': 11.45}, {'name': 'B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.22}, {'name': 'B8', 'common_name': 'pan', 'gsd': 30, 'center_wavelength': 0.71}]}
# 2     {'datetime': '2019-11-18', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.97114851, 'eo:sun_elevation': 23.69548072, 'eo:platform': 'LANDSAT_7', 'eo:instrument': 'ETM', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019322EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.49}, {'name': 'B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.66}, {'name': 'B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.84}, {'name': 'B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.65}, {'name': 'B6', 'common_name': 'tir', 'gsd': 30, 'center_wavelength': 11.45}, {'name': 'B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.22}, {'name': 'B8', 'common_name': 'pan', 'gsd': 30, 'center_wavelength': 0.71}]}
# 3     {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_7', 'eo:off_nadir': 0, 'datetime': '2019-11-18', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 159.97114851, 'eo:sun_elevation': 23.69548072, 'eo:instrument': 'ETM', 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LE70370292019322EDC00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B2', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B3', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B4', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B5', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
# 4     {'collection': 'landsat-c2l2-sr', 'eo:gsd': 30, 'eo:platform': 'LANDSAT_8', 'eo:off_nadir': 0, 'datetime': '2019-10-25', 'eo:cloud_cover': 5.16, 'eo:sun_azimuth': 163.07242715, 'eo:sun_elevation': 31.67198614, 'eo:instrument': 'OLI_TIRS', 'landsat:cloud_cover_land': 5.16, 'landsat:wrs_type': '2', 'landsat:wrs_path': '37', 'landsat:wrs_row': '29', 'landsat:scene_id': 'LC80370292019298LGN00', 'landsat:collection_category': 'T1', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'SR_B1', 'common_name': 'coastal', 'gsd': 30, 'center_wavelength': 0.44}, {'name': 'SR_B2', 'common_name': 'blue', 'gsd': 30, 'center_wavelength': 0.48}, {'name': 'SR_B3', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.56}, {'name': 'SR_B4', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'SR_B5', 'common_name': 'nir08', 'gsd': 30, 'center_wavelength': 0.86}, {'name': 'SR_B6', 'common_name': 'swir16', 'gsd': 30, 'center_wavelength': 1.6}, {'name': 'SR_B7', 'common_name': 'swir22', 'gsd': 30, 'center_wavelength': 2.2}]}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 1154  {'datetime': '1983-01-15', 'eo:cloud_cover': 8, 'eo:sun_azimuth': 151.49493766, 'eo:sun_elevation': 19.15118087, 'eo:platform': 'LANDSAT_4', 'eo:instrument': 'MSS', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 11, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LM40370291983015AAA03', 'landsat:collection_category': 'T2', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.55}, {'name': 'B2', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'B3', 'common_name': 'nir07', 'gsd': 30, 'center_wavelength': 0.75}, {'name': 'B4', 'common_name': 'nir09', 'gsd': 30, 'center_wavelength': 0.95}]}
# 1155  {'datetime': '1982-10-16', 'eo:cloud_cover': 6, 'eo:sun_azimuth': 152.02937047, 'eo:sun_elevation': 32.49448788, 'eo:platform': 'LANDSAT_3', 'eo:instrument': 'MSS', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 8, 'landsat:wrs_type': '1', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LM30370291982289AAA10', 'landsat:collection_category': 'T2', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B4', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.55}, {'name': 'B5', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'B6', 'common_name': 'nir07', 'gsd': 30, 'center_wavelength': 0.75}, {'name': 'B7', 'common_name': 'nir09', 'gsd': 30, 'center_wavelength': 0.95}]}
# 1156  {'datetime': '1982-10-11', 'eo:cloud_cover': 17, 'eo:sun_azimuth': 151.35924483, 'eo:sun_elevation': 34.11115041, 'eo:platform': 'LANDSAT_4', 'eo:instrument': 'MSS', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 21, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LM40370291982284AAA03', 'landsat:collection_category': 'T2', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.55}, {'name': 'B2', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'B3', 'common_name': 'nir07', 'gsd': 30, 'center_wavelength': 0.75}, {'name': 'B4', 'common_name': 'nir09', 'gsd': 30, 'center_wavelength': 0.95}]}
# 1157  {'datetime': '1982-08-24', 'eo:cloud_cover': 0, 'eo:sun_azimuth': 136.13553285, 'eo:sun_elevation': 48.87961417, 'eo:platform': 'LANDSAT_4', 'eo:instrument': 'MSS', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 0, 'landsat:wrs_type': '2', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LM40370291982236AAA02', 'landsat:collection_category': 'T2', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B1', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.55}, {'name': 'B2', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'B3', 'common_name': 'nir07', 'gsd': 30, 'center_wavelength': 0.75}, {'name': 'B4', 'common_name': 'nir09', 'gsd': 30, 'center_wavelength': 0.95}]}
# 1158  {'datetime': '1982-03-14', 'eo:cloud_cover': 1, 'eo:sun_azimuth': 141.79736004, 'eo:sun_elevation': 35.98414837, 'eo:platform': 'LANDSAT_3', 'eo:instrument': 'MSS', 'eo:off_nadir': 0, 'landsat:cloud_cover_land': 1, 'landsat:wrs_type': '1', 'landsat:wrs_path': '037', 'landsat:wrs_row': '029', 'landsat:scene_id': 'LM30370291982073AAA03', 'landsat:collection_category': 'T2', 'landsat:collection_number': '02', 'eo:bands': [{'name': 'B4', 'common_name': 'green', 'gsd': 30, 'center_wavelength': 0.55}, {'name': 'B5', 'common_name': 'red', 'gsd': 30, 'center_wavelength': 0.65}, {'name': 'B6', 'common_name': 'nir07', 'gsd': 30, 'center_wavelength': 0.75}, {'name': 'B7', 'common_name': 'nir09', 'gsd': 30, 'center_wavelength': 0.95}]}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0     {'thumbnail': {'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_thumb_small.jpeg', 'title': 'Thumbnail image', 'type': 'image/jpeg'}, 'reduced_resolution_browse': {'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_thumb_large.jpeg', 'title': 'Reduced resolution browse image', 'type': 'image/jpeg'}, 'index': {'href': 'https://landsatlook.usgs.gov/stac-browser/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1', 'title': 'HTML index page', 'type': 'text/html'}, 'SR_B1.TIF': {'title': 'BLue Band (B1)', 'description': 'Collection 2 Level-2 Blue Band (B1) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [0], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_SR_B1.TIF'}, 'SR_B2.TIF': {'title': 'Green Band (B2)', 'description': 'Collection 2 Level-2 Green Band (B2) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [1], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_SR_B2.TIF'}, 'SR_B3.TIF': {'title': 'Red Band (B3)', 'description': 'Collection 2 Level-2 Red Band (B3) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [2], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191204_20200823_02_T1/LE07_L2SP_037029_20191204_20200823_02_T1_SR_B3.TIF'}, 'SR_B4.TIF': {'title': 'Near Infrared Band 0.8 (B4)', 'description': 'Collection 2 Level-2 Near Infrared Band 0.8 (B4) Surface
20200823_02_T1_SR_B1.TIF'}, 'SR_B2.TIF': {'title': 'Green Band (B2)', 'description': 'Collection 2 Level-2 Green Band (B2) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [1], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_B2.TIF'}, 'SR_B3.TIF': {'title': 'Red Band (B3)', 'description': 'Collection 2 Level-2 Red Band (B3) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [2], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_B3.TIF'}, 'SR_B4.TIF': {'title': 'Near Infrared Band 0.8 (B4)', 'description': 'Collection 2 Level-2 Near Infrared Band 0.8 (B4) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [3], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_B4.TIF'}, 'SR_B5.TIF': {'title': 'Short-wave Infrared Band 1.6 (B5)', 'description': 'Collection 2 Level-2 Short-wave Infrared Band 1.6 (B6) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [4], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_B5.TIF'}, 'SR_B7.TIF': {'title': 'Short-wave Infrared Band 2.2 (B7)', 'description': 'Collection 2 Level-2 Short-wave Infrared Band 2.2 (B7) Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'eo:bands': [5], 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_B7.TIF'}, 'SR_ATMOS_OPACITY.TIF': {'title': 'Atmospheric Opacity Band', 'description': 'Collection 2 Level-2 Atmospheric Opacity Band Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_ATMOS_OPACITY.TIF'}, 'SR_CLOUD_QA.TIF': {'title': 'Cloud Quality Analysis Band', 'description': 'Collection 2 Level-2 Cloud Quality Opacity Band Surface Reflectance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'href': 'https://landsatlook.usgs.gov/data/collection02/level-2/standard/etm/2019/037/029/LE07_L2SP_037029_20191118_20200823_02_T1/LE07_L2SP_037029_20191118_20200823_02_T1_SR_CLOUD_QA.TIF'}, 'ANG.txt': {'title': 'Angle Coefficients File', 'description': 'Collection 2 Level-2 Angle Coefficients File (ANG) Su ...
{'title': 'Product Metadata File (json)', 'description': 'Collection 2 Level-1 Product Metadata File (json) Top of Atmosphere Radiance', 'type': 'application/json', 'href': 'https://landsatlook.usgs.gov/data/collection02/level-1/standard/mss/1982/037/029/LM03_L1TP_037029_19820314_20200904_02_T2/LM03_L1TP_037029_19820314_20200904_02_T2_MTL.json'}, 'QA_PIXEL.TIF': {'title': 'Quality Assessment Band', 'description': 'Collection 2 Level-1 Quality Assessment Band (QA_PIXEL) Top of Atmosphere Radiance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'href': 'https://landsatlook.usgs.gov/data/collection02/level-1/standard/mss/1982/037/029/LM03_L1TP_037029_19820314_20200904_02_T2/LM03_L1TP_037029_19820314_20200904_02_T2_QA_PIXEL.TIF'}, 'QA_RADSAT.TIF': {'title': 'Radiometric Saturation Quality Assessment Band', 'description': 'Radiometric Saturation Quality Assessment Band Top of Atmosphere Radiance', 'type': 'image/vnd.stac.geotiff; cloud-optimized=true', 'href': 'https: ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      links  \
# 0     [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LE07_L2SP_037029_20191204_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1     [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LE07_L1TP_037029_20191204_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 2     [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LE07_L1TP_037029_20191118_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 3     [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LE07_L2SP_037029_20191118_20200823_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 4     [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr/items/LC08_L2SP_037029_20191025_20200825_02_T1'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l2-sr'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 1154  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LM04_L1TP_037029_19830115_20200904_02_T2'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1155  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LM03_L1GS_037029_19821016_20200904_02_T2'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1156  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LM04_L1TP_037029_19821011_20200904_02_T2'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1157  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LM04_L1GS_037029_19820824_20200904_02_T2'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
# 1158  [{'rel': 'self', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1/items/LM03_L1TP_037029_19820314_20200904_02_T2'}, {'rel': 'parent', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'collection', 'href': 'https://landsatlook.usgs.gov/sat-api/collections/landsat-c2l1'}, {'rel': 'root', 'href': 'https://landsatlook.usgs.gov/sat-api/stac'}]
#
#            collection
# 0     landsat-c2l2-sr
# 1     landsat-c2l1
# 2     landsat-c2l1
# 3     landsat-c2l2-sr
# 4     landsat-c2l2-sr
# ...               ...
# 1154  landsat-c2l1
# 1155  landsat-c2l1
# 1156  landsat-c2l1
# 1157  landsat-c2l1
# 1158  landsat-c2l1
#
# [1159 rows x 11 columns]

# %%
#remove everything forward of /collection from the cloudfront object URL
greens = pd.DataFrame(greens['Green'].str[33:])
swirs = pd.DataFrame(swirs['Swirs'].str[33:])
#append s3://usgs-landsat to the front of the URLs
greens = pd.DataFrame("s3://usgs-landsat"+greens['Green'])
swirs = pd.DataFrame("s3://usgs-landsat"+swirs['Swirs'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-f8c70c8666a5> in <module>
#       1 #remove everything forward of /collection from the cloudfront object URL
# ----> 2 greens = pd.DataFrame(greens['Green'].str[33:])
#       3 swirs = pd.DataFrame(swirs['Swirs'].str[33:])
#       4 #append s3://usgs-landsat to the front of the URLs
#       5 greens = pd.DataFrame("s3://usgs-landsat"+greens['Green'])
#
# TypeError: list indices must be integers or slices, not str

# %%
#make a new table with S3 links for objects
df = pd.concat([ids, dates, greens, swirs], axis = 1, sort=False)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-afcee8fa2da0> in <module>
#       1 #make a new table with S3 links for objects
# ----> 2 df = pd.concat([ids, dates, greens, swirs], axis = 1, sort=False)
#       3 df
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     357                     "only Series and DataFrame objs are valid"
#     358                 )
# --> 359                 raise TypeError(msg)
#     360
#     361             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'list'>'; only Series and DataFrame objs are valid

# %%
#Add Date/Time Constructor to Date Column of DF
df['Date'] = pd.to_datetime(df['Date'])

# %%
#Make a seasonality List to show only products where month acquired is May to September
df = df[df['Date'].dt.month.between(5, 9)]
df = df.reset_index(drop=True)
df

# %% [markdown]
# ## Purpose: Extracting an area of interest from a Landsat scene and visualizing change over time by using Xrarry and Holoviews.

# %%
# from dask_kubernetes import KubeCluster
# from dask.distributed import Client
# from dask.distributed import wait, progress
import os
import geopandas as gpd
import folium
from folium import Marker
import cartopy.crs as ccrs
import xarray as xr
import hvplot.xarray
import holoviews as hv
import rasterio as rio
from rasterio.session import AWSSession
import boto3
hv.extension('bokeh', width=90)

# %%
#Show scene extent against AOI. We will eventuly slice the array by the AOI to process only the data we need
gf = features[1]['geometry']
geoms = gpd.read_file('Waubay_AOI.geojson')
m = folium.Map([46.0732, -97.7783], zoom_start=7, width=900, height=350, tiles='OpenStreetMap')
folium.GeoJson(gf).add_to(m)
folium.GeoJson(geoms).add_to(m)
m.add_child(Marker(location=[45.3676, -97.4048], popup='Waubay, South Dakota AOI', icon = folium.Icon(color = 'red')))
folium.LatLngPopup().add_to(m)
m

# %% [markdown]
# # No Kubernetes on the mini-pangeo - just use client

# %%
#This allows us to use Dask with the requester pays bucket
os.environ["AWS_REQUEST_PAYER"] = "requester" 
#cluster = KubeCluster(env={'AWS_REQUEST_PAYER': 'requester'})
# cluster
#Click Manual Scaling
#Add 10 to the Workers Field
#Click Scale
#Click the Dashboard Link and open in a new window to view compute

# %%
#client = Client()

# %%
#client

# %%
#client = Client(cluster)

# %%
aws_session = AWSSession(boto3.Session(), requester_pays=True)

# %%
#Extract corners from AOI to use to subset array
crs = ccrs.epsg(32614)
bounds = geoms.geometry.bounds
bounds.describe()

# %%
lower_left_corner_lat_lon = bounds.minx.min(), bounds.miny.min()
upper_right_corner_lat_lon = bounds.maxx.max(), bounds.maxy.max()

print(lower_left_corner_lat_lon, upper_right_corner_lat_lon)

# %%
ll_corner = crs.transform_point(*lower_left_corner_lat_lon, ccrs.PlateCarree())
ur_corner = crs.transform_point(*upper_right_corner_lat_lon, ccrs.PlateCarree())

print(ll_corner, ur_corner)

# %%
#Function used to create array from data stored in dataframe table created above
def create_dataset(row, bands = ['Swirs', 'Green'], chunks = {'band': 1, 'x':2048, 'y':2049}):
    datasets = []
    with rio.Env(aws_session):
        for band in bands:
            url = row[band]
            #da = xr.open_rasterio(url, chunks = chunks)
            da = xr.open_rasterio(url)
            daSub = da.sel(x=slice(ll_corner[0], ur_corner[0]), y=slice(ur_corner[1], ll_corner[1]))
            daSub = daSub.squeeze().drop(labels='band')
            DS = daSub.to_dataset(name = band)
            datasets.append(DS)
        DS = xr.merge(datasets)
        return DS

# %%
# %%time
#load data
datasets = []
for i,row in df.iterrows():
    try:
        print('loading....', row.Date)
        ds = create_dataset(row)
        datasets.append(ds)
    except Exception as e:
        print('Error loading, skipping')
        print(e)

# %%
# %%time
DS = xr.concat(datasets, dim= pd.DatetimeIndex(df.Date.tolist(), name='time'))
print('Dataset Size (Gb): ', DS.nbytes/1e9)
DS

# %%
#Calculate NDWI
MNDWI = (DS['Green'] - DS['Swirs']) / (DS['Green'] + DS['Swirs'])

# %%
# %%time
import pickle

with open('waubay_ndwi.pickle', 'wb') as handle:
    pickle.dump(MNDWI, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
img = MNDWI.hvplot('x', 'y', groupby='time', dynamic=True, rasterize=True, width=700, height=500, cmap='BrBG')
#use the time slider to step through time.

# %%
img

# %%
# import pickle

# with open('drb150c_xarray.pickle', 'rb') as handle:
#     da = pickle.load(handle)

# %%
MNDWI.to_netcdf('water.nc')

# %%
! ls -lh

# %%
! aws s3 ls --request-payer requester s3://usgs-landsat/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF

# %%
# !aws s3 ls --request-payer requester s3://usgs-landsat/l2-al/oli-tirs/2013/010/028/
    
    #albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF

# %%
! wget https://landsatlook.usgs.gov/data/collection02/level-2/albers/oli-tirs/2020/037/029/LC08_L2SP_037029_20201214_20201219_02_A1/LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF

# %%
# !ls -l

# %%
! file LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF

# %%
! head LC08_L2SP_037029_20201214_20201219_02_A1_SR_B2.TIF
