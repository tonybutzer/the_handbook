# %% [markdown]
# # 00-top50-westerns
#
# - you know how your opening a new browser window
#     - and they put click bait in fron of you
#
# - just what are the best westerns
# -
# ## distraction -- that darn Instant Gratification Monkey
#
# cut paste and grep
#
# - place in a pandas df
#
# ![](https://2.bp.blogspot.com/-Itw_OLDmScQ/Upvh0zdThcI/AAAAAAAAGbc/oTJBvQsSgaA/s1600/IGM+RDM+interacting+1.png)
#
#
# https://www.youtube.com/watch?v=arj7oStGLkU

# %%
! ls
# Out:
# 00-top-50-westerns.ipynb  movie_list.txt

# %%
! cat movie_list.txt
# Out:
#  Dodge City (1939)
#  The Sisters Brothers (2018)
#  Buck and the Preacher (1972)
#  Bad Company (1972)
#  Day of Anger (1967)
#  The Great Train Robbery (1903)
#  Broken Arrow (1950)
#  One-Eyed Jacks (1961)
#  Little Big Man (1970)
#  The Left Handed Gun (1958)
#  The Assassination of Jesse James by the Coward Robert Ford (2007)
#  The Shootist (1976)
#  Blazing Saddles (1974)
#  The Tall T (1957)
#  Django (1966)
#  The Magnificent Seven (1960)
#  Bend of the River (1952)
#  A Bullet for the General (1966)
#  Vera Cruz (1954)
#  Ride the High Country (1962)
#  The Shooting (1966)
#  The Outlaw Josey Wales (1976)
#  The Ox-Bow Incident (1943)
#  For a Few Dollars More (1965)
#  Winchester ’73 (1950)
#  True Grit (2010)
#  The Gunfighter (1950)
#  Dead Man (1995)
#  7 Men From Now (1956)
#  A Fistful of Dollars (1964)
#  She Wore a Yellow Ribbon (1949)
#  Shane (1953)
#  3:10 to Yuma (1957)
#  High Noon (1952)
#  Forty Guns (1957)
#  Johnny Guitar (1954)
# ...

# %%
file='movie_list.txt'
with open(file) as f:
    lines = f.read().splitlines()

# %%
lines
# Out:
# [' Dodge City (1939)',
#  ' The Sisters Brothers (2018)',
#  ' Buck and the Preacher (1972)',
#  ' Bad Company (1972)',
#  ' Day of Anger (1967)',
#  ' The Great Train Robbery (1903)',
#  ' Broken Arrow (1950)',
#  ' One-Eyed Jacks (1961)',
#  ' Little Big Man (1970)',
#  ' The Left Handed Gun (1958)',
#  ' The Assassination of Jesse James by the Coward Robert Ford (2007)',
#  ' The Shootist (1976)',
#  ' Blazing Saddles (1974)',
#  ' The Tall T (1957)',
#  ' Django (1966)',
#  ' The Magnificent Seven (1960)',
#  ' Bend of the River (1952)',
#  ' A Bullet for the General (1966)',
#  ' Vera Cruz (1954)',
#  ' Ride the High Country (1962)',
#  ' The Shooting (1966)',
#  ' The Outlaw Josey Wales (1976)',
#  ' The Ox-Bow Incident (1943)',
#  ' For a Few Dollars More (1965)',
#  ' Winchester ’73 (1950)',
#  ' True Grit (2010)',
#  ' The Gunfighter (1950)',
#  ' Dead Man (1995)',
#  ' 7 Men From Now (1956)',
#  ' A Fistful of Dollars (1964)',
#  ' She Wore a Yellow Ribbon (1949)',
# ...

# %%
lines2=[]
for line in lines:
    space_less = line.lstrip()
    print(space_less)
    lines2.append(space_less)
# Out:
# Dodge City (1939)
# The Sisters Brothers (2018)
# Buck and the Preacher (1972)
# Bad Company (1972)
# Day of Anger (1967)
# The Great Train Robbery (1903)
# Broken Arrow (1950)
# One-Eyed Jacks (1961)
# Little Big Man (1970)
# The Left Handed Gun (1958)
# The Assassination of Jesse James by the Coward Robert Ford (2007)
# The Shootist (1976)
# Blazing Saddles (1974)
# The Tall T (1957)
# Django (1966)
# The Magnificent Seven (1960)
# Bend of the River (1952)
# A Bullet for the General (1966)
# Vera Cruz (1954)
# Ride the High Country (1962)
# The Shooting (1966)
# The Outlaw Josey Wales (1976)
# The Ox-Bow Incident (1943)
# For a Few Dollars More (1965)
# Winchester ’73 (1950)
# True Grit (2010)
# The Gunfighter (1950)
# Dead Man (1995)
# 7 Men From Now (1956)
# A Fistful of Dollars (1964)
# She Wore a Yellow Ribbon (1949)
# Shane (1953)
# 3:10 to Yuma (1957)
# High Noon (1952)
# Forty Guns (1957)
# Johnny Guitar (1954)
# My Darling Clementine (1946)
# ...

# %%
lines2
# Out:
# ['Dodge City (1939)',
#  'The Sisters Brothers (2018)',
#  'Buck and the Preacher (1972)',
#  'Bad Company (1972)',
#  'Day of Anger (1967)',
#  'The Great Train Robbery (1903)',
#  'Broken Arrow (1950)',
#  'One-Eyed Jacks (1961)',
#  'Little Big Man (1970)',
#  'The Left Handed Gun (1958)',
#  'The Assassination of Jesse James by the Coward Robert Ford (2007)',
#  'The Shootist (1976)',
#  'Blazing Saddles (1974)',
#  'The Tall T (1957)',
#  'Django (1966)',
#  'The Magnificent Seven (1960)',
#  'Bend of the River (1952)',
#  'A Bullet for the General (1966)',
#  'Vera Cruz (1954)',
#  'Ride the High Country (1962)',
#  'The Shooting (1966)',
#  'The Outlaw Josey Wales (1976)',
#  'The Ox-Bow Incident (1943)',
#  'For a Few Dollars More (1965)',
#  'Winchester ’73 (1950)',
#  'True Grit (2010)',
#  'The Gunfighter (1950)',
#  'Dead Man (1995)',
#  '7 Men From Now (1956)',
#  'A Fistful of Dollars (1964)',
#  'She Wore a Yellow Ribbon (1949)',
#  'Shane (1953)',
# ...

# %%
import pandas as pd
df = pd.DataFrame(lines2, columns=['movie_title',])

# %%
df
# Out:
#                                           movie_title
# 0                                   Dodge City (1939)
# 1                         The Sisters Brothers (2018)
# 2                        Buck and the Preacher (1972)
# 3                                  Bad Company (1972)
# 4                                 Day of Anger (1967)
# 5                      The Great Train Robbery (1903)
# 6                                 Broken Arrow (1950)
# 7                               One-Eyed Jacks (1961)
# 8                               Little Big Man (1970)
# 9                          The Left Handed Gun (1958)
# 10  The Assassination of Jesse James by the Coward...
# 11                                The Shootist (1976)
# 12                             Blazing Saddles (1974)
# 13                                  The Tall T (1957)
# 14                                      Django (1966)
# 15                       The Magnificent Seven (1960)
# ...

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                                           movie_title
# 0   Dodge City (1939)
# 1   The Sisters Brothers (2018)
# 2   Buck and the Preacher (1972)
# 3   Bad Company (1972)
# 4   Day of Anger (1967)
# 5   The Great Train Robbery (1903)
# 6   Broken Arrow (1950)
# 7   One-Eyed Jacks (1961)
# 8   Little Big Man (1970)
# 9   The Left Handed Gun (1958)
# 10  The Assassination of Jesse James by the Coward Robert Ford (2007)
# 11  The Shootist (1976)
# 12  Blazing Saddles (1974)
# 13  The Tall T (1957)
# 14  Django (1966)
# 15  The Magnificent Seven (1960)
# 16  Bend of the River (1952)
# 17  A Bullet for the General (1966)
# 18  Vera Cruz (1954)
# 19  Ride the High Country (1962)
# 20  The Shooting (1966)
# 21  The Outlaw Josey Wales (1976)
# 22  The Ox-Bow Incident (1943)
# 23  For a Few Dollars More (1965)
# 24  Winchester ’73 (1950)
# 25  True Grit (2010)
# 26  The Gunfighter (1950)
# 27  Dead Man (1995)
# 28  7 Men From Now (1956)
# 29  A Fistful of Dollars (1964)
# ...

# %%
df['status'] = 'null'

# %%
df
# Out:
#                                                           movie_title status
# 0   Dodge City (1939)                                                  null
# 1   The Sisters Brothers (2018)                                        null
# 2   Buck and the Preacher (1972)                                       null
# 3   Bad Company (1972)                                                 null
# 4   Day of Anger (1967)                                                null
# 5   The Great Train Robbery (1903)                                     null
# 6   Broken Arrow (1950)                                                null
# 7   One-Eyed Jacks (1961)                                              null
# 8   Little Big Man (1970)                                              null
# 9   The Left Handed Gun (1958)                                         null
# 10  The Assassination of Jesse James by the Coward Robert Ford (2007)  null
# ...

# %% [markdown]
# https://queirozf.com/entries/pandas-indexing-examples-accessing-and-setting-values-on-dataframes

# %%
df.loc[38,'status'] = 'todo'

# %%
df.loc[48,'status'] = 'todo'

# %%
df
# Out:
#                                                           movie_title status
# 0   Dodge City (1939)                                                  null
# 1   The Sisters Brothers (2018)                                        null
# 2   Buck and the Preacher (1972)                                       null
# 3   Bad Company (1972)                                                 null
# 4   Day of Anger (1967)                                                null
# 5   The Great Train Robbery (1903)                                     null
# 6   Broken Arrow (1950)                                                null
# 7   One-Eyed Jacks (1961)                                              null
# 8   Little Big Man (1970)                                              null
# 9   The Left Handed Gun (1958)                                         null
# 10  The Assassination of Jesse James by the Coward Robert Ford (2007)  null
# ...

# %%
# df.loc[df['column_name'] == some_value]

# %%
df.loc[df['status'] == 'todo']
# Out:
#                               movie_title status
# 38  The Good, the Bad and the Ugly (1966)  todo
# 48  Unforgiven (1992)                      todo

# %% [markdown]
# ---
# ---
#
# ![https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/600px-Pandas_logo.svg.png](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/600px-Pandas_logo.svg.png)

# %%
! grep -i out movie_list.txt
# Out:
#  The Outlaw Josey Wales (1976)

# %%
# Netflix Intersecion - was null

# %% [markdown]
# # Plan B
#
# - Free State of Jones (2016)
# - The Hateful Eight (2015)
# - The Ballad of Buster Scrugs (2018)
# - Hickok (2017)
# - The Outsider (2019)
# - Badland (2019)
# - Hostiles (2017)
# - The Killer (2017)
# - There will be Blood (2007)
#
# https://www.google.com/search?client=firefox-b-1-d&q=westerns+on+netflix
